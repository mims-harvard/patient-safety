# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading-data" data-toc-modified-id="Loading-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Loading data</a></span><ul class="toc-item"><li><span><a href="#Sanity-check" data-toc-modified-id="Sanity-check-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Sanity check</a></span></li><li><span><a href="#Loading-all-reprots" data-toc-modified-id="Loading-all-reprots-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Loading all reprots</a></span></li><li><span><a href="#Narrow-down-based-on-country-and-qualification" data-toc-modified-id="Narrow-down-based-on-country-and-qualification-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Narrow down based on country and qualification</a></span></li></ul></li><li><span><a href="#Generate-data-for-all-patients" data-toc-modified-id="Generate-data-for-all-patients-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Generate data for all patients</a></span><ul class="toc-item"><li><span><a href="#Generate-data" data-toc-modified-id="Generate-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Generate data</a></span><ul class="toc-item"><li><span><a href="#Sanity-check" data-toc-modified-id="Sanity-check-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Sanity check</a></span></li></ul></li><li><span><a href="#Population-distribution" data-toc-modified-id="Population-distribution-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Population distribution</a></span></li></ul></li><li><span><a href="#Conditioned-on-Gender" data-toc-modified-id="Conditioned-on-Gender-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Conditioned on Gender</a></span><ul class="toc-item"><li><span><a href="#Male" data-toc-modified-id="Male-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Male</a></span></li><li><span><a href="#Female" data-toc-modified-id="Female-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Female</a></span></li></ul></li><li><span><a href="#Conditioned-on-Age" data-toc-modified-id="Conditioned-on-Age-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conditioned on Age</a></span><ul class="toc-item"><li><span><a href="#Bin-age-into-groups" data-toc-modified-id="Bin-age-into-groups-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Bin age into groups</a></span></li><li><span><a href="#Three-age-groups" data-toc-modified-id="Three-age-groups-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Three age groups</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Loading data
#
# We investigate period from 03-11 to 09-30 from 2013 to 2020. If anyone want to analyze different time period, just replace the start or end time. For example, replace '09-30' by '12-31' to study the period from March 11 to December 31.

# %%
import itertools
from tqdm import tqdm
from collections import Counter
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests
# %matplotlib notebook
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import warnings
warnings.filterwarnings('ignore')

# load the dictionaries for drugs, AE
se_dic = pickle.load(open('../Data/curated/AE_mapping.pk', 'rb'))
drug_dic = pickle.load(open('../Data/curated/drug_dic.pk', 'rb'))

# In this MeDRA_dic, key is string of PT_name, value is a list:
# [PT, PT_name, HLT,HLT_name,HLGT,HLGT_name,SOC,SOC_name,SOC_abbr]
meddra_pd_all = pickle.load(open('../Data/curated/drug_mapping.pk', 'rb'))

# %%
def chi_sq(A, B,C,D):
    A, B, C,D = A.astype(float), B.astype(float), C.astype(float), D.astype(float)
    numerator =(A*D-B*C)**2
    denominator = (A+B)*(C+D)*(A+C)*(B+D)
    numerator = numerator/denominator
    numerator_ = numerator*(A+B+C+D)
    return numerator_

def lower_CI(A, B,C,D, ROR):
    A, B, C,D, ROR = A.astype(float), B.astype(float), C.astype(float), D.astype(float), ROR.astype(float)
    s = np.sqrt(1/A+ 1/B + 1/C +1/D)
    CI_low = np.e**(np.log(ROR)-1.96*s)
#     CI_high = e**(np.log(ROR)+1.96*s)
    return CI_low

# %% [markdown]
# ## Sanity check

# %%
meddra_pd_all.head(1)
# Out:
#          PT                         PT_name       HLT  \
# 0  10000002  11-beta-hydroxylase deficiency  10021608
#
#                              HLT_name      HLGT  \
# 0  inborn errors of steroid synthesis  10027424
#
#                                         HLGT_name       SOC  \
# 0  metabolic and nutritional disorders congenital  10010331
#
#                                      SOC_name SOC_abbr
# 0  congenital, familial and genetic disorders     Cong

# %%
meddra_pd_all[meddra_pd_all.PT=='10018358']
# Out:
#          PT                               PT_name       HLT  \
# 0  10018358  glomerular filtration rate decreased  10038454
#
#                   HLT_name      HLGT  \
# 0  renal function analyses  10038362
#
#                                            HLGT_name       SOC  \
# 0  renal and urinary tract investigations and uri...  10022891
#
#          SOC_name SOC_abbr
# 0  investigations      Inv

# %%
# drug dictionary to df
drug_dic_pd = pd.DataFrame(drug_dic)
drug_dic_df = drug_dic_pd.T

drug_dic_df.columns=['drugbank_ID', 'code']
drug_dic_df.head()
# Out:
#                 drugbank_ID code
# etanercept          DB00005    4
# zoledronic acid     DB00399  334
# atorvastatin        DB01076  931
# metformin           DB00331  274
# rosiglitazone       DB00412  343

# %%
drug_dic_df[drug_dic_df.code == 931]
# drug_dic['remdesivir']

# Make a drug_code_dic to find the drug name by code
drug_code_dic = {}
for key, value in drug_dic.items():
    drug_code_dic[value[-1]]=[key, value[0]]
pickle.dump(drug_code_dic, open('../Data/parsed/drug_code_dic.pk', 'wb'))
drug_code_dic
# Out:
# {4: ['etanercept', 'DB00005'],
#  334: ['zoledronic acid', 'DB00399'],
#  931: ['atorvastatin', 'DB01076'],
#  274: ['metformin', 'DB00331'],
#  343: ['rosiglitazone', 'DB00412'],
#  174: ['glimepiride', 'DB00222'],
#  305: ['levonorgestrel', 'DB00367'],
#  1077: ['epoprostenol', 'DB01240'],
#  1060: ['budesonide', 'DB01222'],
#  626: ['imiquimod', 'DB00724'],
#  855: ['formoterol', 'DB00983'],
#  704: ['ribavirin', 'DB00811'],
#  1781: ['boceprevir', 'DB08873'],
#  7: ['peginterferon alfa-2a', 'DB00008'],
#  383: ['loratadine', 'DB00455'],
#  1798: ['mirabegron', 'DB08893'],
#  380: ['levothyroxine', 'DB00451'],
#  598: ['furosemide', 'DB00695'],
#  969: ['amiodarone', 'DB01118'],
#  277: ['olanzapine', 'DB00334'],
#  1075: ['aripiprazole', 'DB01238'],
#  314: ['trihexyphenidyl', 'DB00376'],
#  919: ['oxybutynin', 'DB01062'],
#  1088: ['dasatinib', 'DB01254'],
#  658: ['clopidogrel', 'DB00758'],
#  118: ['ergocalciferol', 'DB00153'],
#  40: ['adalimumab', 'DB00051'],
#  87: ['cyanocobalamin', 'DB00115'],
#  36: ['insulin glargine', 'DB00047'],
#  1106: ['varenicline', 'DB01273'],
#  1635: ['liraglutide', 'DB06655'],
#  1125: ['insulin glulisine', 'DB01309'],
#  1089: ['lisdexamfetamine', 'DB01255'],
#  950: ['leflunomide', 'DB01097'],
#  544: ['prednisone', 'DB00635'],
#  130: ['cholecalciferol', 'DB00169'],
#  1152: ['calcium', 'DB01373'],
#  22: ['human immunoglobulin g', 'DB00028'],
#  68: ['cyclosporine', 'DB00091'],
#  592: ['mycophenolate mofetil', 'DB00688'],
#  750: ['tacrolimus', 'DB00864'],
#  3454: ['cortisone', 'DB14681'],
#  476: ['bosentan', 'DB00559'],
#  1257: ['deferasirox', 'DB01609'],
#  319: ['amlodipine', 'DB00381'],
#  1168: ['danazol', 'DB01406'],
#  301: ['clozapine', 'DB00363'],
#  1594: ['ambrisentan', 'DB06403'],
#  1070: ['metoclopramide', 'DB01233'],
#  261: ['acetaminophen', 'DB00316'],
#  1153: ['magnesium oxide', 'DB01377'],
#  1008: ['cilostazol', 'DB01166'],
#  1259: ['hydroxychloroquine', 'DB01611'],
#  966: ['nifedipine', 'DB01115'],
#  1590: ['pertuzumab', 'DB06366'],
#  55: ['trastuzumab', 'DB00072'],
#  1083: ['docetaxel', 'DB01248'],
#  266: ['amitriptyline', 'DB00321'],
#  1632: ['denosumab', 'DB06643'],
#  1066: ['paclitaxel', 'DB01229'],
#  641: ['hydrocortisone', 'DB00741'],
#  784: ['ondansetron', 'DB00904'],
#  1921: ['sodium oxybate', 'DB09072'],
#  422: ['oxycodone', 'DB00497'],
#  181: ['pregabalin', 'DB00230'],
#  1557: ['rivaroxaban', 'DB06228'],
#  1828: ['obinutuzumab', 'DB08935'],
#  924: ['promethazine', 'DB01069'],
#  954: ['capecitabine', 'DB01101'],
#  446: ['oxaliplatin', 'DB00526'],
#  85: ['bevacizumab', 'DB00112'],
#  241: ['etonogestrel', 'DB00294'],
#  1810: ['fluticasone furoate', 'DB08906'],
#  163: ['azithromycin', 'DB00207'],
#  250: ['desogestrel', 'DB00304'],
#  1487: ['telaprevir', 'DB05521'],
#  236: ['atomoxetine', 'DB00289'],
#  1006: ['calcium chloride', 'DB01164'],
#  460: ['benazepril', 'DB00542'],
#  1123: ['insulin aspart', 'DB01306'],
#  312: ['treprostinil', 'DB00374'],
#  19: ['peginterferon alfa-2b', 'DB00022'],
#  2546: ['rebamipide', 'DB11656'],
#  1579: ['simeprevir', 'DB06290'],
#  407: ['celecoxib', 'DB00482'],
#  280: ['omeprazole', 'DB00338'],
#  56: ['rituximab', 'DB00073'],
#  459: ['vincristine', 'DB00541'],
#  450: ['cyclophosphamide', 'DB00531'],
#  746: ['prednisolone', 'DB00860'],
#  869: ['doxorubicin', 'DB00997'],
#  984: ['levofloxacin', 'DB01137'],
#  1039: ['zopiclone', 'DB01198'],
#  221: ['topiramate', 'DB00273'],
#  169: ['citalopram', 'DB00215'],
#  414: ['sotalol', 'DB00489'],
#  3470: ['dabigatran', 'DB14726'],
#  923: ['clonazepam', 'DB01068'],
#  289: ['clobazam', 'DB00349'],
#  868: ['gabapentin', 'DB00996'],
#  583: ['losartan', 'DB00678'],
#  971: ['gliclazide', 'DB01120'],
#  136: ['fluvoxamine', 'DB00176'],
#  135: ['pravastatin', 'DB00175'],
#  802: ['cyclobenzaprine', 'DB00924'],
#  354: ['zolpidem', 'DB00425'],
#  278: ['atenolol', 'DB00335'],
#  600: ['tizanidine', 'DB00697'],
#  333: ['sorafenib', 'DB00398'],
#  497: ['lactulose', 'DB00581'],
#  45: ['interferon beta-1a', 'DB00060'],
#  480: ['methotrexate', 'DB00563'],
#  718: ['diazepam', 'DB00829'],
#  144: ['lorazepam', 'DB00186'],
#  405: ['lenalidomide', 'DB00480'],
#  92: ['choline', 'DB00122'],
#  377: ['lansoprazole', 'DB00448'],
#  213: ['metoprolol', 'DB00264'],
#  907: ['memantine', 'DB01043'],
#  586: ['warfarin', 'DB00682'],
#  1017: ['escitalopram', 'DB01175'],
#  1071: ['dexamethasone', 'DB01234'],
#  609: ['tamsulosin', 'DB00706'],
#  661: ['potassium chloride', 'DB00761'],
#  555: ['nystatin', 'DB00646'],
#  951: ['rosuvastatin', 'DB01098'],
#  1051: ['ceftriaxone', 'DB01212'],
#  1379: ['nimesulide', 'DB04743'],
#  1554: ['lacosamide', 'DB06218'],
#  660: ['meropenem', 'DB00760'],
#  116: ['cysteine', 'DB00151'],
#  59: ['daptomycin', 'DB00080'],
#  683: ['acyclovir', 'DB00787'],
#  1524: ['teicoplanin', 'DB06149'],
#  2974: ['lenograstim', 'DB13144'],
#  564: ['trazodone', 'DB00656'],
#  585: ['amphotericin b', 'DB00681'],
#  987: ['micafungin', 'DB01141'],
#  152: ['fluconazole', 'DB00196'],
#  3515: ['flurbiprofen axetil', 'DB14938'],
#  1548: ['doripenem', 'DB06211'],
#  3404: ['potassium', 'DB14500'],
#  427: ['haloperidol', 'DB00502'],
#  528: ['imatinib', 'DB00619'],
#  904: ['fenofibrate', 'DB01039'],
#  81: ['natalizumab', 'DB00108'],
#  233: ['venlafaxine', 'DB00285'],
#  605: ['icodextrin', 'DB00702'],
#  284: ['diltiazem', 'DB00343'],
#  428: ['ritonavir', 'DB00503'],
#  420: ['zidovudine', 'DB00495'],
#  911: ['abacavir', 'DB01048'],
#  3323: ['tenofovir', 'DB14126'],
#  927: ['atazanavir', 'DB01072'],
#  1723: ['raltegravir', 'DB06817'],
#  2040: ['ubidecarenone', 'DB09270'],
#  785: ['bimatoprost', 'DB00905'],
#  3456: ['calcium polycarbophil', 'DB14684'],
#  137: ['valsartan', 'DB00177'],
#  871: ['hydrochlorothiazide', 'DB00999'],
#  52: ['interferon beta-1b', 'DB00068'],
#  503: ['fluticasone propionate', 'DB00588'],
#  397: ['montelukast', 'DB00471'],
#  35: ['insulin lispro', 'DB00046'],
#  943: ['iloprost', 'DB01088'],
#  562: ['latanoprost', 'DB00654'],
#  624: ['lisinopril', 'DB00722'],
#  2375: ['omega-3 fatty acids', 'DB11133'],
#  983: ['carvedilol', 'DB01136'],
#  768: ['isosorbide dinitrate', 'DB00883'],
#  1982: ['sodium chloride', 'DB09153'],
#  472: ['lamotrigine', 'DB00555'],
#  618: ['paroxetine', 'DB00715'],
#  1547: ['eltrombopag', 'DB06210'],
#  1016: ['phenobarbital', 'DB01174'],
#  481: ['carbamazepine', 'DB00564'],
#  63: ['pancrelipase', 'DB00085'],
#  366: ['allopurinol', 'DB00437'],
#  168: ['pantoprazole', 'DB00213'],
#  865: ['azathioprine', 'DB00993'],
#  449: ['erlotinib', 'DB00530'],
#  263: ['codeine', 'DB00318'],
#  1815: ['trametinib', 'DB08911'],
#  601: ['nitrofurantoin', 'DB00698'],
#  1784: ['taliglucerase alfa', 'DB08876'],
#  1965: ['copper', 'DB09130'],
#  282: ['cetirizine', 'DB00341'],
#  1050: ['clarithromycin', 'DB01211'],
#  956: ['sertraline', 'DB01104'],
#  149: ['tramadol', 'DB00193'],
#  308: ['mirtazapine', 'DB00370'],
#  731: ['donepezil', 'DB00843'],
#  684: ['naproxen', 'DB00788'],
#  1241: ['solifenacin', 'DB01591'],
#  1595: ['human c1-esterase inhibitor', 'DB06404'],
#  1614: ['pazopanib', 'DB06589'],
#  94: ['ascorbic acid', 'DB00126'],
#  502: ['diclofenac', 'DB00586'],
#  706: ['fentanyl', 'DB00813'],
#  920: ['melatonin', 'DB01065'],
#  1496: ['ustekinumab', 'DB05679'],
#  1776: ['fingolimod', 'DB08868'],
#  293: ['aztreonam', 'DB00355'],
#  1101: ['sunitinib', 'DB01268'],
#  242: ['morphine', 'DB00295'],
#  370: ['gemcitabine', 'DB00441'],
#  999: ['bupropion', 'DB01156'],
#  1805: ['teduglutide', 'DB08900'],
#  185: ['reboxetine', 'DB00234'],
#  645: ['modafinil', 'DB00745'],
#  194: ['ranolazine', 'DB00243'],
#  350: ['spironolactone', 'DB00421'],
#  1171: ['tiotropium', 'DB01409'],
#  500: ['enalapril', 'DB00584'],
#  1109: ['exenatide', 'DB01276'],
#  11: ['darbepoetin alfa', 'DB00012'],
#  1114: ['abatacept', 'DB01281'],
#  1827: ['sofosbuvir', 'DB08934'],
#  790: ['paricalcitol', 'DB00910'],
#  765: ['emtricitabine', 'DB00879'],
#  1599: ['etravirine', 'DB06414'],
#  140: ['baclofen', 'DB00181'],
#  435: ['dextromethorphan', 'DB00514'],
#  667: ['olopatadine', 'DB00768'],
#  1124: ['insulin detemir', 'DB01307'],
#  1120: ['glucosamine', 'DB01296'],
#  3275: ['fish oil', 'DB13961'],
#  505: ['doxazosin', 'DB00590'],
#  2133: ['insulin degludec', 'DB09564'],
#  1771: ['pitavastatin', 'DB08860'],
#  1840: ['azosemide', 'DB08961'],
#  839: ['telmisartan', 'DB00966'],
#  2566: ['ipragliflozin', 'DB11698'],
#  846: ['ezetimibe', 'DB00973'],
#  1100: ['paliperidone', 'DB01267'],
#  398: ['fluoxetine', 'DB00472'],
#  1079: ['clomipramine', 'DB01242'],
#  550: ['simvastatin', 'DB00641'],
#  1812: ['dimethyl fumarate', 'DB08908'],
#  1584: ['elotuzumab', 'DB06317'],
#  122: ['folic acid', 'DB00158'],
#  141: ['amphetamine', 'DB00182'],
#  588: ['tobramycin', 'DB00684'],
#  832: ['methylprednisolone', 'DB00959'],
#  1651: ['desvenlafaxine', 'DB06700'],
#  637: ['esomeprazole', 'DB00736'],
#  50: ['follitropin', 'DB00066'],
#  1703: ['ganirelix', 'DB06785'],
#  331: ['progesterone', 'DB00396'],
#  681: ['estradiol', 'DB00783'],
#  1728: ['triptorelin', 'DB06825'],
#  1800: ['tofacitinib', 'DB08895'],
#  438: ['albendazole', 'DB00518'],
#  371: ['entecavir', 'DB00442'],
#  1757: ['ticagrelor', 'DB08816'],
#  3408: ['lithium carbonate', 'DB14509'],
#  488: ['propranolol', 'DB00571'],
#  1062: ['quetiapine', 'DB01224'],
#  487: ['vinblastine', 'DB00570'],
#  738: ['dacarbazine', 'DB00851'],
#  1778: ['brentuximab vedotin', 'DB08870'],
#  2115: ['avobenzone', 'DB09495'],
#  1814: ['pomalidomide', 'DB08910'],
#  524: ['bisoprolol', 'DB00612'],
#  772: ['mechlorethamine', 'DB00888'],
#  1010: ['procarbazine', 'DB01168'],
#  1621: ['apixaban', 'DB06605'],
#  258: ['valproic acid', 'DB00313'],
#  3001: ['valerian', 'DB13196'],
#  401: ['duloxetine', 'DB00476'],
#  49: ['infliximab', 'DB00065'],
#  271: ['hydromorphone', 'DB00327'],
#  3410: ['mometasone furoate', 'DB14512'],
#  455: ['ciprofloxacin', 'DB00537'],
#  587: ['midazolam', 'DB00683'],
#  917: ['amoxicillin', 'DB01060'],
#  275: ['ipratropium', 'DB00332'],
#  2473: ['sennosides', 'DB11365'],
#  543: ['sulfacetamide', 'DB00634'],
#  458: ['nortriptyline', 'DB00540'],
#  806: ['azacitidine', 'DB00928'],
#  1025: ['domperidone', 'DB01184'],
#  1572: ['tocilizumab', 'DB06273'],
#  462: ['fluorouracil', 'DB00544'],
#  558: ['leucovorin', 'DB00650'],
#  1009: ['itraconazole', 'DB01167'],
#  230: ['pamidronic acid', 'DB00282'],
#  764: ['chlorhexidine', 'DB00878'],
#  1802: ['aclidinium', 'DB08897'],
#  760: ['guaifenesin', 'DB00874'],
#  1466: ['glatiramer', 'DB05259'],
#  795: ['metronidazole', 'DB00916'],
#  1043: ['nadolol', 'DB01203'],
#  1973: ['oxygen', 'DB09140'],
#  17: ['pegfilgrastim', 'DB00019'],
#  77: ['octreotide', 'DB00104'],
#  1481: ['iodine', 'DB05382'],
#  1405: ['nebivolol', 'DB04861'],
#  912: ['ibuprofen', 'DB01050'],
#  2895: ['bcg vaccine', 'DB12768'],
#  23: ['insulin human', 'DB00030'],
#  1254: ['tazobactam', 'DB01606'],
#  709: ['propofol', 'DB00818'],
#  264: ['piperacillin', 'DB00319'],
#  345: ['ampicillin', 'DB00415'],
#  172: ['moxifloxacin', 'DB00218'],
#  1073: ['sevoflurane', 'DB01236'],
#  1247: ['imipenem', 'DB01598'],
#  367: ['ceftazidime', 'DB00438'],
#  1576: ['teriparatide', 'DB06285'],
#  1523: ['mianserin', 'DB06148'],
#  1220: ['bromazepam', 'DB01558'],
#  3023: ['tropatepine', 'DB13252'],
#  635: ['risperidone', 'DB00734'],
#  1353: ['valpromide', 'DB04165'],
#  730: ['oxazepam', 'DB00842'],
#  886: ['minocycline', 'DB01017'],
#  33: ['omalizumab', 'DB00043'],
#  492: ['clonidine', 'DB00575'],
#  474: ['hydroxyzine', 'DB00557'],
#  568: ['metaxalone', 'DB00660'],
#  740: ['temozolomide', 'DB00853'],
#  1351: ['fotemustine', 'DB04106'],
#  773: ['granisetron', 'DB00889'],
#  1042: ['levetiracetam', 'DB01202'],
#  575: ['sumatriptan', 'DB00669'],
#  744: ['terbinafine', 'DB00857'],
#  674: ['oxcarbazepine', 'DB00776'],
#  1240: ['everolimus', 'DB01590'],
#  1495: ['apremilast', 'DB05676'],
#  1546: ['prasugrel', 'DB06209'],
#  138: ['ramipril', 'DB00178'],
#  1787: ['teriflunomide', 'DB08880'],
#  638: ['meclizine', 'DB00737'],
#  338: ['alprazolam', 'DB00404'],
#  928: ['fludarabine', 'DB01073'],
#  1250: ['lopinavir', 'DB01601'],
#  612: ['lamivudine', 'DB00709'],
#  229: ['lidocaine', 'DB00281'],
#  467: ['propylthiouracil', 'DB00550'],
#  260: ['zolmitriptan', 'DB00315'],
#  249: ['ertapenem', 'DB00303'],
#  1797: ['linaclotide', 'DB08890'],
#  351: ['methylphenidate', 'DB00422'],
#  484: ['cephalexin', 'DB00567'],
#  529: ['triamcinolone', 'DB00620'],
#  160: ['dofetilide', 'DB00204'],
#  1650: ['degarelix', 'DB06699'],
#  1653: ['fesoterodine', 'DB06702'],
#  831: ['carboplatin', 'DB00958'],
#  897: ['topotecan', 'DB01030'],
#  1763: ['lomitapide', 'DB08827'],
#  203: ['doxycycline', 'DB00254'],
#  1785: ['ruxolitinib', 'DB08877'],
#  949: ['fluvastatin', 'DB01095'],
#  1502: ['abiraterone', 'DB05812'],
#  978: ['bicalutamide', 'DB01128'],
#  1626: ['bosutinib', 'DB06616'],
#  1834: ['iopamidol', 'DB08947'],
#  909: ['lubiprostone', 'DB01046'],
#  1146: ['iohexol', 'DB01362'],
#  1801: ['regorafenib', 'DB08896'],
#  891: ['felodipine', 'DB01023'],
#  1094: ['sitagliptin', 'DB01261'],
#  372: ['betamethasone', 'DB00443'],
#  3179: ['pristinamycin', 'DB13704'],
#  1880: ['aliskiren', 'DB09026'],
#  1940: ['tixocortol', 'DB09091'],
#  1160: ['colchicine', 'DB01394'],
#  1526: ['acetylcysteine', 'DB06151'],
#  968: ['atovaquone', 'DB01117'],
#  1673: ['calcium carbonate', 'DB06724'],
#  1161: ['drospirenone', 'DB01395'],
#  1825: ['macitentan', 'DB08932'],
#  216: ['ropinirole', 'DB00268'],
#  922: ['glipizide', 'DB01067'],
#  711: ['tadalafil', 'DB00820'],
#  1804: ['enzalutamide', 'DB08899'],
#  353: ['hyoscyamine', 'DB00424'],
#  1531: ['canakinumab', 'DB06168'],
#  725: ['loperamide', 'DB00836'],
#  91: ['biotin', 'DB00121'],
#  963: ['cefuroxime', 'DB01112'],
#  930: ['diphenhydramine', 'DB01075'],
#  857: ['dimenhydrinate', 'DB00985'],
#  561: ['magnesium sulfate', 'DB00653'],
#  326: ['digoxin', 'DB00390'],
#  1031: ['clindamycin', 'DB01190'],
#  2340: ['docusate', 'DB11089'],
#  1756: ['lurasidone', 'DB08815'],
#  231: ['clemastine', 'DB00283'],
#  6: ['leuprolide', 'DB00007'],
#  15: ['erythropoietin', 'DB00016'],
#  365: ['bendroflumethiazide', 'DB00436'],
#  329: ['beclomethasone dipropionate', 'DB00394'],
#  1788: ['vemurafenib', 'DB08881'],
#  2128: ['omega-3-acid ethyl esters', 'DB09539'],
#  147: ['carbidopa', 'DB00190'],
#  952: ['flucytosine', 'DB01099'],
#  3029: ['sitafloxacin', 'DB13261'],
#  433: ['vancomycin', 'DB00512'],
#  201: ['phenytoin', 'DB00252'],
#  1092: ['lapatinib', 'DB01259'],
#  286: ['alfuzosin', 'DB00346'],
#  1462: ['cobimetinib', 'DB05239'],
#  1545: ['silodosin', 'DB06207'],
#  896: ['irbesartan', 'DB01029'],
#  976: ['dutasteride', 'DB01126'],
#  1477: ['romiplostim', 'DB05332'],
#  826: ['rizatriptan', 'DB00953'],
#  1538: ['icatibant', 'DB06196'],
#  1475: ['ecallantide', 'DB05311'],
#  1103: ['ranibizumab', 'DB01270'],
#  805: ['famotidine', 'DB00927'],
#  707: ['meloxicam', 'DB00814'],
#  1792: ['aflibercept', 'DB08885'],
#  1932: ['ivabradine', 'DB09083'],
#  2775: ['canrenone', 'DB12221'],
#  749: ['ranitidine', 'DB00863'],
#  489: ['atropine', 'DB00572'],
#  1242: ['iron', 'DB01592'],
#  272: ['indomethacin', 'DB00328'],
#  794: ['amantadine', 'DB00915'],
#  515: ['ivermectin', 'DB00602'],
#  2791: ['propiverine', 'DB12278'],
#  789: ['zonisamide', 'DB00909'],
#  690: ['candesartan cilexetil', 'DB00796'],
#  2876: ['urapidil', 'DB12661'],
#  569: ['verapamil', 'DB00661'],
#  792: ['repaglinide', 'DB00912'],
#  2851: ['piritramide', 'DB12492'],
#  878: ['ketoprofen', 'DB01009'],
#  699: ['pentoxifylline', 'DB00806'],
#  2163: ['ambrosia artemisiifolia pollen', 'DB10385'],
#  1789: ['linagliptin', 'DB08882'],
#  1904: ['ibrutinib', 'DB09053'],
#  516: ['medroxyprogesterone acetate', 'DB00603'],
#  344: ['pramipexole', 'DB00413'],
#  800: ['buprenorphine', 'DB00921'],
#  142: ['nicotine', 'DB00184'],
#  906: ['melphalan', 'DB01042'],
#  905: ['thalidomide', 'DB01041'],
#  1648: ['artemether', 'DB06697'],
#  566: ['sevelamer', 'DB00658'],
#  2116: ['octinoxate', 'DB09496'],
#  1760: ['ivacaftor', 'DB08820'],
#  935: ['vigabatrin', 'DB01080'],
#  1633: ['ofatumumab', 'DB06650'],
#  1692: ['bendamustine', 'DB06769'],
#  965: ['chlorpheniramine', 'DB01114'],
#  1: ['cetuximab', 'DB00002'],
#  662: ['irinotecan', 'DB00762'],
#  509: ['amiloride', 'DB00594'],
#  885: ['glyburide', 'DB01016'],
#  854: ['isotretinoin', 'DB00982'],
#  225: ['theophylline', 'DB00277'],
#  247: ['flucloxacillin', 'DB00301'],
#  663: ['methimazole', 'DB00763'],
#  1574: ['levocetirizine', 'DB06282'],
#  375: ['chloramphenicol', 'DB00446'],
#  1191: ['alfacalcidol', 'DB01436'],
#  3120: ['alginic acid', 'DB13518'],
#  1913: ['ciprofibrate', 'DB09064'],
#  514: ['linezolid', 'DB00601'],
#  539: ['alendronic acid', 'DB00630'],
#  812: ['oxymetazoline', 'DB00935'],
#  979: ['rabeprazole', 'DB01129'],
#  889: ['isosorbide mononitrate', 'DB01020'],
#  823: ['fexofenadine', 'DB00950'],
#  1541: ['alogliptin', 'DB06203'],
#  1402: ['febuxostat', 'DB04854'],
#  1178: ['acenocoumarol', 'DB01418'],
#  486: ['fondaparinux', 'DB00569'],
#  536: ['niacin', 'DB00627'],
#  767: ['quinapril', 'DB00881'],
#  406: ['raloxifene', 'DB00481'],
#  533: ['testosterone', 'DB00624'],
#  808: ['colesevelam', 'DB00930'],
#  182: ['temazepam', 'DB00231'],
#  1063: ['enoxaparin', 'DB01225'],
#  1662: ['naphazoline', 'DB06711'],
#  579: ['aprepitant', 'DB00673'],
#  2263: ['flax seed', 'DB10708'],
#  189: ['nevirapine', 'DB00238'],
#  1641: ['sipuleucel-t', 'DB06688'],
#  178: ['lovastatin', 'DB00227'],
#  861: ['rivastigmine', 'DB00989'],
#  321: ['triamterene', 'DB00384'],
#  1630: ['dalfampridine', 'DB06637'],
#  1764: ['vismodegib', 'DB08828'],
#  748: ['vardenafil', 'DB00862'],
#  1809: ['certolizumab pegol', 'DB08904'],
#  1055: ['finasteride', 'DB01216'],
#  102: ['lutein', 'DB00137'],
#  2244: ['cranberry', 'DB10631'],
#  2322: ['carboxymethylcellulose', 'DB11059'],
#  845: ['azelastine', 'DB00972'],
#  392: ['ketorolac', 'DB00465'],
#  227: ['liothyronine', 'DB00279'],
#  3411: ['magnesium', 'DB14513'],
#  1549: ['tolvaptan', 'DB06212'],
#  1696: ['capsaicin', 'DB06774'],
#  155: ['erythromycin', 'DB00199'],
#  535: ['bacitracin', 'DB00626'],
#  615: ['flurbiprofen', 'DB00712'],
#  1956: ['stiripentol', 'DB09118'],
#  159: ['sildenafil', 'DB00203'],
#  3381: ['saw palmetto', 'DB14360'],
#  1410: ['vildagliptin', 'DB04876'],
#  498: ['voriconazole', 'DB00582'],
#  1575: ['ziconotide', 'DB06283'],
#  534: ['efavirenz', 'DB00625'],
#  74: ['filgrastim', 'DB00099'],
#  2003: ['loxoprofen', 'DB09212'],
#  1004: ['terazosin', 'DB01162'],
#  2346: ['plantago seed', 'DB11097'],
#  1478: ['dexlansoprazole', 'DB05351'],
#  409: ['brimonidine', 'DB00484'],
#  256: ['chlorthalidone', 'DB00310'],
#  859: ['cytarabine', 'DB00987'],
#  613: ['ibandronate', 'DB00710'],
#  352: ['methocarbamol', 'DB00423'],
#  1542: ['tapentadol', 'DB06204'],
#  649: ['etodolac', 'DB00749'],
#  1774: ['crizotinib', 'DB08865'],
#  146: ['bortezomib', 'DB00188'],
#  1985: ['iopromide', 'DB09156'],
#  1598: ['armodafinil', 'DB06413'],
#  617: ['apomorphine', 'DB00714'],
#  470: ['methoxsalen', 'DB00553'],
#  471: ['piroxicam', 'DB00554'],
#  1639: ['vilazodone', 'DB06684'],
#  1580: ['dapagliflozin', 'DB06292'],
#  1275: ['roflumilast', 'DB01656'],
#  1902: ['elosulfase alfa', 'DB09051'],
#  453: ['cefdinir', 'DB00535'],
#  540: ['clofarabine', 'DB00631'],
#  597: ['daunorubicin', 'DB00694'],
#  1019: ['idarubicin', 'DB01177'],
#  910: ['fluocinonide', 'DB01047'],
#  988: ['doxepin', 'DB01142'],
#  330: ['carisoprodol', 'DB00395'],
#  105: ['riboflavin', 'DB00140'],
#  2354: ['magnesium citrate', 'DB11110'],
#  1078: ['gemfibrozil', 'DB01241'],
#  325: ['carbimazole', 'DB00389'],
#  1628: ['axitinib', 'DB06626'],
#  771: ['bumetanide', 'DB00887'],
#  1535: ['ipilimumab', 'DB06186'],
#  863: ['oxaprozin', 'DB00991'],
#  993: ['nefazodone', 'DB01149'],
#  299: ['vinorelbine', 'DB00361'],
#  982: ['pioglitazone', 'DB01132'],
#  678: ['phenelzine', 'DB00780'],
#  415: ['buspirone', 'DB00490'],
#  1038: ['captopril', 'DB01197'],
#  3216: ['clopamide', 'DB13792'],
#  3345: ['egg phospholipids', 'DB14233'],
#  3047: ['tetrazepam', 'DB13324'],
#  1072: ['levodopa', 'DB01235'],
#  374: ['epirubicin', 'DB00445'],
#  829: ['hydrocodone', 'DB00956'],
#  1818: ['afatinib', 'DB08916'],
#  647: ['scopolamine', 'DB00747'],
#  1018: ['cyclizine', 'DB01176'],
#  1157: ['sodium bicarbonate', 'DB01390'],
#  170: ['eletriptan', 'DB00216'],
#  1056: ['anastrozole', 'DB01217'],
#  302: ['sucralfate', 'DB00364'],
#  884: ['sulfamethoxazole', 'DB01015'],
#  852: ['ramelteon', 'DB00980'],
#  3609: ['prednisolone acetate', 'DB15566'],
#  1301: ['vorinostat', 'DB02546'],
#  3447: ['dexamethasone acetate', 'DB14649'],
#  1150: ['rasagiline', 'DB01367'],
#  1645: ['xylometazoline', 'DB06694'],
#  1957: ['eslicarbazepine acetate', 'DB09119'],
#  822: ['felbamate', 'DB00949'],
#  197: ['cabergoline', 'DB00248'],
#  475: ['zanamivir', 'DB00558'],
#  753: ['ritodrine', 'DB00867'],
#  1754: ['nadroparin', 'DB08813'],
#  1796: ['carfilzomib', 'DB08889'],
#  837: ['apraclonidine', 'DB00964'],
#  1091: ['eculizumab', 'DB01257'],
#  444: ['metolazone', 'DB00524'],
#  1112: ['galsulfase', 'DB01279'],
#  448: ['foscarnet', 'DB00529'],
#  1258: ['valganciclovir', 'DB01610'],
#  65: ['alemtuzumab', 'DB00087'],
#  1097: ['darunavir', 'DB01264'],
#  1726: ['tinzaparin', 'DB06822'],
#  551: ['pemetrexed', 'DB00642'],
#  436: ['cisplatin', 'DB00515'],
#  2509: ['human rho(d) immune globulin', 'DB11597'],
#  1637: ['golimumab', 'DB06674'],
#  2165: ['phleum pratense pollen', 'DB10394'],
#  1699: ['dalteparin', 'DB06779'],
#  686: ['perindopril', 'DB00790'],
#  701: ['indapamide', 'DB00808'],
#  1104: ['idursulfase', 'DB01271'],
#  1786: ['belimumab', 'DB08879'],
#  763: ['sirolimus', 'DB00877'],
#  76: ['agalsidase beta', 'DB00103'],
#  362: ['prochlorperazine', 'DB00433'],
#  2329: ['dimethicone', 'DB11074'],
#  3240: ['fluticasone', 'DB13867'],
#  199: ['dapsone', 'DB00250'],
#  580: ['galantamine', 'DB00674'],
#  2018: ['benidipine', 'DB09231'],
#  337: ['eszopiclone', 'DB00402'],
#  1023: ['propafenone', 'DB01182'],
#  1912: ['ceritinib', 'DB09063'],
#  1408: ['nilotinib', 'DB04868'],
#  117: ['thiamine', 'DB00152'],
#  1816: ['dabrafenib', 'DB08912'],
#  841: ['methyldopa', 'DB00968'],
#  1888: ['nivolumab', 'DB09035'],
#  419: ['entacapone', 'DB00494'],
#  1811: ['canagliflozin', 'DB08907'],
#  796: ['dinoprostone', 'DB00917'],
#  349: ['promazine', 'DB00420'],
#  2971: ['fluindione', 'DB13136'],
#  881: ['cinacalcet', 'DB01012'],
#  970: ['diazoxide', 'DB01119'],
#  164: ['ticlopidine', 'DB00208'],
#  1461: ['beraprost', 'DB05229'],
#  532: ['fluphenazine', 'DB00623'],
#  892: ['mycophenolic acid', 'DB01024'],
#  1426: ['permethrin', 'DB04930'],
#  689: ['sulfasalazine', 'DB00795'],
#  651: ['epinastine', 'DB00751'],
#  1175: ['cefepime', 'DB01413'],
#  38: ['rasburicase', 'DB00049'],
#  671: ['etoposide', 'DB00773'],
#  1022: ['ifosfamide', 'DB01181'],
#  629: ['nitroglycerin', 'DB00727'],
#  342: ['mupirocin', 'DB00410'],
#  2057: ['ramosetron', 'DB09290'],
#  2143: ['bacillus calmette-guerin substrain tice live antigen', 'DB10343'],
#  101: ['calcitriol', 'DB00136'],
#  387: ['verteporfin', 'DB00460'],
#  1654: ['gadobutrol', 'DB06703'],
#  2095: ['isosorbide', 'DB09401'],
#  1758: ['hyaluronic acid', 'DB08818'],
#  1565: ['droxidopa', 'DB06262'],
#  1473: ['eldecalcitol', 'DB05295'],
#  1061: ['aminophylline', 'DB01223'],
#  145: ['esmolol', 'DB00187'],
#  1672: ['aluminum hydroxide', 'DB06723'],
#  133: ['adenine', 'DB00173'],
#  2344: ['calcium citrate', 'DB11093'],
#  877: ['busulfan', 'DB01008'],
#  1383: ['metamizole', 'DB04817'],
#  593: ['flurazepam', 'DB00690'],
#  1782: ['fidaxomicin', 'DB08874'],
#  369: ['trimethoprim', 'DB00440'],
#  2508: ['levoleucovorin', 'DB11596'],
#  2029: ['gimeracil', 'DB09257'],
#  223: ['olmesartan', 'DB00275'],
#  1154: ['cortisone acetate', 'DB01380'],
#  1551: ['ferumoxytol', 'DB06215'],
#  887: ['guanfacine', 'DB01018'],
#  1245: ['nitrazepam', 'DB01595'],
#  875: ['letrozole', 'DB01006'],
#  815: ['salmeterol', 'DB00938'],
#  156: ['hydroxocobalamin', 'DB00200'],
#  1719: ['povidone-iodine', 'DB06812'],
#  2237: ['wheat', 'DB10579'],
#  3243: ['fenofibric acid', 'DB13873'],
#  228: ['disopyramide', 'DB00280'],
#  21: ['anakinra', 'DB00026'],
#  1207: ['delorazepam', 'DB01511'],
#  633: ['atracurium besylate', 'DB00732'],
#  3261: ['candesartan', 'DB13919'],
#  379: ['droperidol', 'DB00450'],
#  902: ['tolterodine', 'DB01036'],
#  238: ['chlorambucil', 'DB00291'],
#  2530: ['isavuconazole', 'DB11633'],
#  946: ['butenafine', 'DB01091'],
#  2071: ['zinc oxide', 'DB09321'],
#  1102: ['panitumumab', 'DB01269'],
#  2898: ['benserazide', 'DB12783'],
#  3225: ['oxomemazine', 'DB13820'],
#  27: ['desmopressin', 'DB00035'],
#  315: ['palonosetron', 'DB00377'],
#  1096: ['posaconazole', 'DB01263'],
#  127: ['pyridoxine', 'DB00165'],
#  900: ['mercaptopurine', 'DB01033'],
#  1877: ['bisacodyl', 'DB09020'],
#  1243: ['zinc', 'DB01593'],
#  177: ['gadodiamide', 'DB00225'],
#  1428: ['ospemifene', 'DB04938'],
#  563: ['estrone', 'DB00655'],
#  620: ['adefovir dipivoxil', 'DB00718'],
#  1592: ['bazedoxifene', 'DB06401'],
#  1117: ['fenoterol', 'DB01288'],
#  882: ['clobetasol propionate', 'DB01013'],
#  1093: ['desonide', 'DB01260'],
#  2862: ['mebeverine', 'DB12554'],
#  8: ['alteplase', 'DB00009'],
#  1876: ['bromhexine', 'DB09019'],
#  2463: ['bacillus subtilis', 'DB11347'],
#  41: ['imiglucerase', 'DB00053'],
#  1108: ['hydralazine', 'DB01275'],
#  1399: ['celiprolol', 'DB04846'],
#  819: ['phenprocoumon', 'DB00946'],
#  688: ['primidone', 'DB00794'],
#  363: ['cyproheptadine', 'DB00434'],
#  1130: ['cefazolin', 'DB01327'],
#  291: ['megestrol acetate', 'DB00351'],
#  244: ['bupivacaine', 'DB00297'],
#  1272: ['etoricoxib', 'DB01628'],
#  148: ['phentermine', 'DB00191'],
#  13: ['goserelin', 'DB00014'],
#  820: ['fulvestrant', 'DB00947'],
#  1806: ['ponatinib', 'DB08901'],
#  1775: ['ulipristal', 'DB08867'],
#  1695: ['cabazitaxel', 'DB06772'],
#  1472: ['vandetanib', 'DB05294'],
#  581: ['tamoxifen', 'DB00675'],
#  780: ['triazolam', 'DB00897'],
#  3242: ['lormetazepam', 'DB13872'],
#  603: ['eplerenone', 'DB00700'],
#  2589: ['clobetasol', 'DB11750'],
#  2045: ['bismuth subcitrate potassium', 'DB09275'],
#  1471: ['rotigotine', 'DB05271'],
#  894: ['ketoconazole', 'DB01026'],
#  384: ['prazosin', 'DB00457'],
#  1666: ['potassium iodide', 'DB06715'],
#  866: ['neomycin', 'DB00994'],
#  276: ['methadone', 'DB00333'],
#  517: ['cisapride', 'DB00604'],
#  824: ['isoniazid', 'DB00951'],
#  1550: ['regadenoson', 'DB06213'],
#  84: ['daclizumab', 'DB00111'],
#  3620: ['carbomer', 'DB15649'],
#  1871: ['carbazochrome', 'DB09012'],
#  2784: ['tulobuterol', 'DB12248'],
#  682: ['mefenamic acid', 'DB00784'],
#  2934: ['phloroglucinol', 'DB12944'],
#  1978: ['water', 'DB09145'],
#  574: ['epinephrine', 'DB00668'],
#  960: ['heparin', 'DB01109'],
#  1824: ['riociguat', 'DB08931'],
#  1613: ['minodronic acid', 'DB06548'],
#  874: ['hydroxyurea', 'DB01005'],
#  1671: ['velaglucerase alfa', 'DB06720'],
#  2023: ['manidipine', 'DB09238'],
#  858: ['glycopyrronium', 'DB00986'],
#  78: ['interferon alfa-2b', 'DB00105'],
#  262: ['gefitinib', 'DB00317'],
#  388: ['nabumetone', 'DB00461'],
#  2440: ['diacetyl benzoyl lathyrol', 'DB11260'],
#  273: ['ethambutol', 'DB00330'],
#  526: ['rifabutin', 'DB00615'],
#  2025: ['moxonidine', 'DB09242'],
#  508: ['ethosuximide', 'DB00593'],
#  1446: ['indacaterol', 'DB05039'],
#  2327: ['pancrelipase amylase', 'DB11065'],
#  653: ['isoflurane', 'DB00753'],
#  1059: ['ketamine', 'DB01221'],
#  630: ['rocuronium', 'DB00728'],
#  1223: ['chloral hydrate', 'DB01563'],
#  676: ['roxithromycin', 'DB00778'],
#  1813: ['glycerol phenylbutyrate', 'DB08909'],
#  440: ['caspofungin', 'DB00520'],
#  157: ['caffeine', 'DB00201'],
#  3398: ['ferrous fumarate', 'DB14491'],
#  1218: ['cloxazolam', 'DB01553'],
#  698: ['dicyclomine', 'DB00804'],
#  873: ['ganciclovir', 'DB01004'],
#  311: ['timolol', 'DB00373'],
#  1783: ['cabozantinib', 'DB08875'],
#  761: ['flupentixol', 'DB00875'],
#  1377: ['hesperidin', 'DB04703'],
#  692: ['gentamicin', 'DB00798'],
#  1918: ['trimetazidine', 'DB09069'],
#  2001: ['piracetam', 'DB09210'],
#  1819: ['ferric carboxymaltose', 'DB08917'],
#  840: ['desloratadine', 'DB00967'],
#  2759: ['bucillamine', 'DB12160'],
#  82: ['enfuvirtide', 'DB00109'],
#  281: ['pyrazinamide', 'DB00339'],
#  237: ['bleomycin', 'DB00290'],
#  1217: ['dihydrocodeine', 'DB01551'],
#  1947: ['daclatasvir', 'DB09102'],
#  1036: ['flecainide', 'DB01195'],
#  1403: ['dronedarone', 'DB04855'],
#  2359: ['ensulizole', 'DB11115'],
#  520: ['chloroquine', 'DB00608'],
#  447: ['lercanidipine', 'DB00528'],
#  1795: ['ocriplasmin', 'DB08888'],
#  1793: ['asparaginase erwinia chrysanthemi', 'DB08886'],
#  862: ['exemestane', 'DB00990'],
#  939: ['emedastine', 'DB01084'],
#  1215: ['ethyl loflazepate', 'DB01545'],
#  703: ['biperiden', 'DB00810'],
#  2909: ['tandospirone', 'DB12833'],
#  1214: ['flunitrazepam', 'DB01544'],
#  1085: ['olsalazine', 'DB01250'],
#  400: ['chlordiazepoxide', 'DB00475'],
#  1040: ['bromocriptine', 'DB01200'],
#  452: ['rofecoxib', 'DB00533'],
#  602: ['nicergoline', 'DB00699'],
#  700: ['proparacaine', 'DB00807'],
#  1540: ['rufinamide', 'DB06201'],
#  724: ['brompheniramine', 'DB00835'],
#  1905: ['idelalisib', 'DB09054'],
#  1491: ['ramucirumab', 'DB05578'],
#  1649: ['betahistine', 'DB06698'],
#  439: ['trandolapril', 'DB00519'],
#  2369: ['calcium gluconate', 'DB11126'],
#  382: ['meperidine', 'DB00454'],
#  1447: ['erdosteine', 'DB05057'],
#  1992: ['etizolam', 'DB09166'],
#  2060: ['talniflumate', 'DB09295'],
#  1415: ['bepotastine', 'DB04890'],
#  926: ['mequitazine', 'DB01071'],
#  2055: ['propacetamol', 'DB09288'],
#  848: ['dipyridamole', 'DB00975'],
#  396: ['dronabinol', 'DB00470'],
#  1116: ['corticotropin', 'DB01285'],
#  606: ['methazolamide', 'DB00703'],
#  1874: ['brotizolam', 'DB09017'],
#  1681: ['ambroxol', 'DB06742'],
#  1007: ['ofloxacin', 'DB01165'],
#  1970: ['technetium tc-99m mebrofenin', 'DB09137'],
#  1975: ['sincalide', 'DB09142'],
#  1708: ['lanthanum carbonate', 'DB06792'],
#  1573: ['alvimopan', 'DB06274'],
#  1307: ['fusidic acid', 'DB02703'],
#  737: ['perphenazine', 'DB00850'],
#  3409: ['acetate', 'DB14511'],
#  1759: ['tafluprost', 'DB08819'],
#  1035: ['brinzolamide', 'DB01194'],
#  3420: ['hydrocortisone butyrate', 'DB14540'],
#  1617: ['agomelatine', 'DB06594'],
#  28: ['coagulation factor viia recombinant human', 'DB00036'],
#  1463: ['silver sulfadiazine', 'DB05245'],
#  913: ['nitrendipine', 'DB01054'],
#  1917: ['vortioxetine', 'DB09068'],
#  2583: ['rilmenidine', 'DB11738'],
#  813: ['salicylic acid', 'DB00936'],
#  1189: ['cholestyramine', 'DB01432'],
#  1398: ['ixabepilone', 'DB04845'],
#  1869: ['articaine', 'DB09009'],
#  445: ['tolnaftate', 'DB00525'],
#  1707: ['lanreotide', 'DB06791'],
#  655: ['tretinoin', 'DB00755'],
#  161: ['pyrimethamine', 'DB00205'],
#  1979: ['iron sucrose', 'DB09146'],
#  2342: ['hydrogen peroxide', 'DB11091'],
#  57: ['basiliximab', 'DB00074'],
#  723: ['mifepristone', 'DB00834'],
#  402: ['chlorpromazine', 'DB00477'],
#  757: ['terbutaline', 'DB00871'],
#  3142: ['metopimazine', 'DB13591'],
#  2225: ['karaya gum', 'DB10535'],
#  175: ['diflorasone', 'DB00223'],
#  1886: ['vedolizumab', 'DB09033'],
#  675: ['propiomazine', 'DB00777'],
#  3039: ['atracurium', 'DB13295'],
#  2609: ['imidapril', 'DB11783'],
#  211: ['carmustine', 'DB00262'],
#  1095: ['decitabine', 'DB01262'],
#  3026: ['ferrous sulfate anhydrous', 'DB13257'],
#  632: ['nateglinide', 'DB00731'],
#  1046: ['lomustine', 'DB01206'],
#  1024: ['naloxone', 'DB01183'],
#  1790: ['perampanel', 'DB08883'],
#  1914: ['cobicistat', 'DB09065'],
#  693: ['tazarotene', 'DB00799'],
#  1159: ['bezafibrate', 'DB01393'],
#  2190: ['saccharomyces cerevisiae', 'DB10447'],
#  1034: ['acebutolol', 'DB01193'],
#  2560: ['selumetinib', 'DB11689'],
#  3419: ['hydrocortisone acetate', 'DB14539'],
#  769: ['risedronic acid', 'DB00884'],
#  2665: ['deflazacort', 'DB11921'],
#  3268: ['testosterone undecanoate', 'DB13946'],
#  297: ['sulfadiazine', 'DB00359'],
#  2124: ['hydroquinone', 'DB09526'],
#  2065: ['butylscopolamine', 'DB09300'],
#  255: ['vindesine', 'DB00309'],
#  26: ['interferon gamma-1b', 'DB00033'],
#  195: ['ziprasidone', 'DB00246'],
#  1890: ['pembrolizumab', 'DB09037'],
#  3024: ['propatyl nitrate', 'DB13255'],
#  754: ['benzonatate', 'DB00868'],
#  205: ['lymecycline', 'DB00256'],
#  787: ['cocaine', 'DB00907'],
#  2745: ['vinpocetine', 'DB12131'],
#  1015: ['orphenadrine', 'DB01173'],
#  251: ['mitomycin', 'DB00305'],
#  166: ['adapalene', 'DB00210'],
#  206: ['clotrimazole', 'DB00257'],
#  735: ['cysteamine', 'DB00847'],
#  1084: ['iodixanol', 'DB01249'],
#  304: ['doxylamine', 'DB00366'],
#  1636: ['pasireotide', 'DB06663'],
#  1942: ['benzoyl peroxide', 'DB09096'],
#  1562: ['eflornithine', 'DB06243'],
#  1162: ['digitoxin', 'DB01396'],
#  2337: ['cocoa butter', 'DB11086'],
#  513: ['thiopental', 'DB00599'],
#  158: ['succinylcholine', 'DB00202'],
#  1136: ['pancuronium', 'DB01337'],
#  2503: ['carbon monoxide', 'DB11588'],
#  2688: ['uprosertib', 'DB11969'],
#  2222: ['garlic', 'DB10532'],
#  1861: ['cyamemazine', 'DB09000'],
#  961: ['miconazole', 'DB01110'],
#  560: ['pentazocine', 'DB00652'],
#  1105: ['alglucosidase alfa', 'DB01272'],
#  2393: ['sodium sulfide', 'DB11159'],
#  67: ['laronidase', 'DB00090'],
#  323: ['procyclidine', 'DB00387'],
#  288: ['nitisinone', 'DB00348'],
#  355: ['famciclovir', 'DB00426'],
#  512: ['labetalol', 'DB00598'],
#  702: ['tropicamide', 'DB00809'],
#  1193: ['phenazopyridine', 'DB01438'],
#  3201: ['magnesium gluconate', 'DB13749'],
#  139: ['flunisolide', 'DB00180'],
#  664: ['mometasone', 'DB00764'],
#  2102: ['insulin beef', 'DB09456'],
#  1948: ['magnesium hydroxide', 'DB09104'],
#  2821: ['bromperidol', 'DB12401'],
#  729: ['dobutamine', 'DB00841'],
#  269: ['fluorometholone', 'DB00324'],
#  1238: ['prazepam', 'DB01588'],
#  3412: ['magnesium lactate', 'DB14515'],
#  2320: ['mineral oil', 'DB11057'],
#  417: ['fosinopril', 'DB00492'],
#  1262: ['aceprometazine', 'DB01615'],
#  1256: ['periciazine', 'DB01608'],
#  1878: ['benfluorex', 'DB09022'],
#  2697: ['diacerein', 'DB11994'],
#  1424: ['clevidipine', 'DB04920'],
#  3005: ['bamifylline', 'DB13203'],
#  18: ['sargramostim', 'DB00020'],
#  3151: ['potassium gluconate', 'DB13620'],
#  43: ['gemtuzumab ozogamicin', 'DB00056'],
#  797: ['almotriptan', 'DB00918'],
#  710: ['acetazolamide', 'DB00819'],
#  1118: ['pirbuterol', 'DB01291'],
#  576: ['pirenzepine', 'DB00670'],
#  992: ['flavoxate', 'DB01148'],
#  1239: ['quazepam', 'DB01589'],
#  2009: ['nicorandil', 'DB09220'],
#  2019: ['cilnidipine', 'DB09232'],
#  2907: ['gabexate', 'DB12831'],
#  2585: ['ebastine', 'DB11742'],
#  3168: ['dexchlorpheniramine', 'DB13679'],
#  496: ['valdecoxib', 'DB00580'],
#  2012: ['blonanserin', 'DB09223'],
#  2015: ['barnidipine', 'DB09227'],
#  306: ['norepinephrine', 'DB00368'],
#  611: ['sufentanil', 'DB00708'],
#  2797: ['nefopam', 'DB12293'],
#  423: ['phenindione', 'DB00498'],
#  44: ['pegaspargase', 'DB00059'],
#  1113: ['nelarabine', 'DB01280'],
#  2511: ['tuberculin purified protein derivative', 'DB11601'],
#  2: ['dornase alfa', 'DB00003'],
#  1919: ['tibolone', 'DB09070'],
#  2096: ['magnesium chloride', 'DB09407'],
#  234: ['travoprost', 'DB00287'],
#  243: ['ropivacaine', 'DB00296'],
#  327: ['sulpiride', 'DB00391'],
#  2282: ['bacillus calmette-guerin substrain connaught live antigen',
#   'DB10804'],
#  834: ['mepivacaine', 'DB00961'],
#  3251: ['human cytomegalovirus immune globulin', 'DB13886'],
#  3388: ['influenza a virus a/california/7/2009 x-181 (h1n1) antigen (formaldehyde inactivated)',
#   'DB14455'],
#  1943: ['quinagolide', 'DB09097'],
#  1668: ['fosaprepitant', 'DB06717'],
#  1069: ['saquinavir', 'DB01232'],
#  2500: ['thiocolchicoside', 'DB11582'],
#  192: ['butalbital', 'DB00241'],
#  607: ['naltrexone', 'DB00704'],
#  1397: ['tetrabenazine', 'DB04844'],
#  3580: ['hydroquinidine', 'DB15300'],
#  766: ['chlorothiazide', 'DB00880'],
#  62: ['botulinum toxin type a', 'DB00083'],
#  165: ['trospium', 'DB00209'],
#  482: ['cisatracurium', 'DB00565'],
#  1127: ['fosphenytoin', 'DB01320'],
#  1411: ['voglibose', 'DB04878'],
#  465: ['azelaic acid', 'DB00548'],
#  1577: ['temsirolimus', 'DB06287'],
#  1716: ['plerixafor', 'DB06809'],
#  180: ['cefotiam', 'DB00229'],
#  781: ['remifentanil', 'DB00899'],
#  1441: ['ingenol mebutate', 'DB05013'],
#  2499: ['venetoclax', 'DB11581'],
#  1049: ['levobunolol', 'DB01210'],
#  2130: ['dexchlorpheniramine maleate', 'DB09555'],
#  477: ['tigecycline', 'DB00560'],
#  1875: ['bromopride', 'DB09018'],
#  ...}

# %%
# side effect dictionary to dataframe
SE_dic_pd = pd.DataFrame(SE_dic)
SE_dic_df = SE_dic_pd.T

SE_dic_df.columns=['medra_ID', 'code']
SE_dic_df.head()
# Out:
#                                        medra_ID   code
# death                                  C1306577  12818
# osteonecrosis of jaw                   C2711248  14718
# general physical health deterioration  C0877211  10470
# pain                                   C0030193   1878
# anxiety                                C0003467    152

# %%
# convert code to name.
list(SE_dic_df[SE_dic_df.code==152].index)[0]
# Out:
# 'anxiety'

# %%
SE_dic_df[SE_dic_df.index == 'pneumonia']

# Make a SE_code_dic to find the SE name by code
SE_code_dic = {}
for key, value in SE_dic.items():
    SE_code_dic[value[-1]]=[key, value[0]]
# key is code, [name, umls ID]
pickle.dump(SE_code_dic, open('../Data/parsed/SE_code_dic.pk', 'wb'))

# %% [markdown]
# ## Loading all reprots

# %%
all_pd = pickle.load(open('../Data/curated/patient_safety.pk', 'rb'))  

all_pd.head(3)
# Out:
#   version report_id          case_id country qualify serious s1 s2 s3 s4 s5  \
# 0      18   6161368  PHEH2006US13340      US       5       1  1  0  1  0  0
# 1       2   7820167  US-ROCHE-735882      US       4       1  0  0  1  0  0
# 2      11   7683841  PHHY2009CA17701      CA       3       1  0  0  1  0  0
#
#   s6  receivedate  receiptdate age gender weight  \
# 0  1         2498         4776  68      2      0
# 1  1         4069         4764  39      2     68
# 2  1         3982         4777  -1      2      0
#
#                                                   SE drugs indications  \
# 0  [10001488, 10002034, 10002855, 10002948, 10003...    []          []
# 1  [10000081, 10003246, 10009900, 10012378, 10013...    []          []
# 2  [10000081, 10000087, 10001949, 10003445, 10006...    []          []
#
#    lastingdays        date receipt_date
# 0         2278  2006-11-03   2013-01-28
# 1          695  2011-02-21   2013-01-16
# 2          795  2010-11-26   2013-01-29

# %% [markdown]
# ## Narrow down based on country and qualification

# %%
all_pd_US = all_pd[all_pd.country=='US']
print('Focus on US, reports #', all_pd_US.shape)

id_qua = [i in ['1', '2', '3'] for i in all_pd_US.qualify ]
all_pd_US_pro = all_pd_US[id_qua]  # professional: 1,2,3
print('Focus on professional qualification, reports #', all_pd_US_pro.shape)

pickle.dump(all_pd_US_pro, open('../Data/pandemic/all_pd_US_pro.pk', 'wb'))
# Out:
# Focus on US, reports # (6351817, 23)
# Focus on professional qualification, reports # (2551071, 23)

# %% [markdown]
# # Generate data for all patients
#
# The overall population (all patients) is denoted by 'uncondition'. Variables with 'uncondition' in name refers to the population of all patients.

# %% [markdown]
# ## Generate data

# %%
all_pd_US_pro = pickle.load(open('../Data/pandemic/all_pd_US_pro.pk', 'rb'))  # update the dataframe with ROR and Delta

# %%
# SE_list = list(SE_dic_df.code)
DF = all_pd_US_pro
SE_list = list(sorted(set(list(itertools.chain(*DF.SE)))))
print('#-SE in US pro',len(SE_list))

ind = [i in SE_list for i in meddra_pd_all.PT]
whatever_ = meddra_pd_all[ind]
print(whatever_.shape)
whatever_.head(3)
# Out:
# #-SE in US pro 15454
# (15454, 9)
#          PT                          PT_name       HLT  \
# 0  10000014  17-alpha-hydroxylase deficiency  10021608
# 0  10000029     5-alpha-reductase deficiency  10021608
# 0  10000044                 abdomen crushing  10083613
#
#                                       HLT_name      HLGT  \
# 0           inborn errors of steroid synthesis  10027424
# 0           inborn errors of steroid synthesis  10027424
# 0  abdominal and gastrointestinal injuries nec  10022114
#
#                                         HLGT_name       SOC  \
# 0  metabolic and nutritional disorders congenital  10010331
# 0  metabolic and nutritional disorders congenital  10010331
# 0                                    injuries nec  10022117
#
#                                          SOC_name SOC_abbr
# 0      congenital, familial and genetic disorders     Cong
# 0      congenital, familial and genetic disorders     Cong
# 0  injury, poisoning and procedural complications    Inj&P

# %%
# reports in 2020 
yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
n_re = []
for yr in yr_list:
    st = str(yr)+'-03-10'
    end = str(yr)+'-09-31'      
    ind = [st<i<end for i in all_pd_US_pro['receipt_date']]  # all ['date'] --> ['receipt_date']
    locals()['all_pd_US_pro_'+str(yr)]= all_pd_US_pro[ind]
    n_reports = len(locals()['all_pd_US_pro_'+str(yr)])
    n_re.append(n_reports)
    print('rows in {}:{}'.format(yr,n_reports))
# Out:
# rows in 2013:89334
# rows in 2014:97804
# rows in 2015:179383
# rows in 2016:169233
# rows in 2017:210736
# rows in 2018:244005
# rows in 2019:220920
# rows in 2020:211152

# %%
yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

"""initialize the Data frame """
se_matrix = pd.DataFrame({'SE': list(whatever_.PT), 'name':list(whatever_['PT_name']) }) #'medra_ID': list(SE_dic_df['medra_ID'])

for yr in yr_list:
    n_report = len(locals()['all_pd_US_pro_'+str(yr)])
    print('{} year has {} reports'.format(yr, n_report))
    A =[]

    for se in tqdm(SE_list):
        name = locals()['all_pd_US_pro_'+str(yr)]
        indx = [se in j for j in name.SE]
        n_A = sum(indx)
        A.append(n_A)
    B = [n_report - i for i in A]
    se_matrix[str(yr)+'_A'] = A
    se_matrix[str(yr)+'_B'] = B
# Out:
#   0%|          | 4/15454 [00:00<06:48, 37.82it/s]
# 2013 year has 89334 reports
# 100%|██████████| 15454/15454 [06:37<00:00, 38.91it/s]
#   0%|          | 4/15454 [00:00<08:02, 32.00it/s]
# 2014 year has 97804 reports
# 100%|██████████| 15454/15454 [07:22<00:00, 34.89it/s]
#   0%|          | 2/15454 [00:00<14:29, 17.77it/s]
# 2015 year has 179383 reports
# 100%|██████████| 15454/15454 [13:44<00:00, 18.75it/s]
#   0%|          | 2/15454 [00:00<14:03, 18.32it/s]
# 2016 year has 169233 reports
# 100%|██████████| 15454/15454 [12:57<00:00, 19.88it/s]
#   0%|          | 2/15454 [00:00<17:20, 14.85it/s]
# 2017 year has 210736 reports
# 100%|██████████| 15454/15454 [16:28<00:00, 15.64it/s]
#   0%|          | 2/15454 [00:00<20:01, 12.86it/s]
# 2018 year has 244005 reports
# 100%|██████████| 15454/15454 [18:34<00:00, 13.87it/s]
#   0%|          | 2/15454 [00:00<18:25, 13.97it/s]
# 2019 year has 220920 reports
# 100%|██████████| 15454/15454 [17:26<00:00, 14.77it/s]
#   0%|          | 2/15454 [00:00<18:05, 14.23it/s]
# 2020 year has 211152 reports
# 100%|██████████| 15454/15454 [17:14<00:00, 14.94it/s]

# %%
pickle.dump(se_matrix, open('../Data/pandemic/SE_uncondition_raw.pk', 'wb'))

# %%
para = se_matrix
yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019]
for yr in yr_list:  # calculate ROR  
    para[str(yr)+'_ROR'] = (para['2020_A']*para[str(yr)+'_B'])/(para['2020_B']*para[str(yr)+'_A'])

for yr in yr_list:  # calculate Delta: average difference  
    para[str(yr)+'_Delta'] = (para['2020_A'] - para[str(yr)+'_A'])/para[str(yr)+'_A']

pd.set_option('display.max_columns', None)
"""Note: 0/0 = NaN, 1/0 = inf"""
para.head()
# Out:
#          SE                             name  2013_A  2013_B  2014_A  2014_B  \
# 0  10000014  17-alpha-hydroxylase deficiency       0   89334       0   97804
# 1  10000029     5-alpha-reductase deficiency       0   89334       0   97804
# 2  10000044                 abdomen crushing       0   89334       0   97804
# 3  10000050              abdominal adhesions      14   89320      14   97790
# 4  10000059             abdominal discomfort     559   88775     613   97191
#
#    2015_A  2015_B  2016_A  2016_B  2017_A  2017_B  2018_A  2018_B  2019_A  \
# 0       1  179382       0  169233       0  210736       0  244005       0
# 1       0  179383       0  169233       0  210736       0  244005       0
# 2       0  179383       0  169233       0  210736       0  244005       0
# 3      16  179367       7  169226      21  210715      16  243989      15
# 4    1402  177981    1446  167787    1999  208737    2400  241605    2145
#
#    2019_B  2020_A  2020_B  2013_ROR  2014_ROR  2015_ROR  2016_ROR  2017_ROR  \
# 0  220920       0  211152       NaN       NaN  0.000000       NaN       NaN
# 1  220920       1  211151       inf       inf       inf       inf       inf
# 2  220920       1  211151       inf       inf       inf       inf       inf
# 3  220905      12  211140  0.362603  0.396988  0.637138  1.373978  0.570278
# 4  218775    1993  209159  1.513246  1.510763  1.209641  1.105658  0.994987
#
#    2018_ROR  2019_ROR  2013_Delta  2014_Delta  2015_Delta  2016_Delta  \
# 0       NaN       NaN         NaN         NaN   -1.000000         NaN
# 1       inf       inf         inf         inf         inf         inf
# 2       inf       inf         inf         inf         inf         inf
# 3  0.866684  0.836999   -0.142857   -0.142857   -0.250000    0.714286
# 4  0.959236  0.971854    2.565295    2.251223    0.421541    0.378285
#
#    2017_Delta  2018_Delta  2019_Delta
# 0         NaN         NaN         NaN
# 1         inf         inf         inf
# 2         inf         inf         inf
# 3   -0.428571   -0.250000   -0.200000
# 4   -0.003002   -0.169583   -0.070862

# %%
pickle.dump(para, open('../Data/pandemic/SE_uncondition.pk', 'wb'))  # update the dataframe with ROR and Delta

# %% [markdown]
# ### Sanity check

# %%
uncondition_2019_history = pickle.load(open('../Data/pandemic/SE_uncondition.pk', 'rb'))

# %%
uncondition_2019_history[uncondition_2019_history.name=='cardiac arrest']
# Out:
#             SE            name  2013_A  2013_B  2014_A  2014_B  2015_A  \
# 1123  10007515  cardiac arrest     525   88809     750   97054     637
#
#       2015_B  2016_A  2016_B  2017_A  2017_B  2018_A  2018_B  2019_A  2019_B  \
# 1123  178746     867  168366     714  210022     667  243338     725  220195
#
#       2020_A  2020_B  2013_ROR  2014_ROR  2015_ROR  2016_ROR  2017_ROR  \
# 1123    1331  209821  1.073067  0.820883  1.780025  1.231869  1.865931
#
#       2018_ROR  2019_ROR  2013_Delta  2014_Delta  2015_Delta  2016_Delta  \
# 1123  2.314266  1.926631    1.535238    0.774667    1.089482    0.535179
#
#       2017_Delta  2018_Delta  2019_Delta
# 1123    0.864146    0.995502    0.835862

# %%
x = uncondition_2019_history[uncondition_2019_history['2019_Delta']>0]
print(x.shape)
y = x[x['2020_A']>1000]
print(y.shape)

y[['SE', 'name','2018_A', '2019_A', '2020_A', '2019_Delta']]
# Out:
# (5724, 32)
# (78, 32)
#              SE                                              name  2018_A  \
# 169    10001551                alanine aminotransferase increased     389
# 246    10002034                                           anaemia    1406
# 355    10002855                                           anxiety    1781
# 433    10003239                                        arthralgia    4331
# 470    10003549                                          asthenia    3164
# 534    10003988                                         back pain    3119
# 903    10005750                          blood pressure increased    1199
# 1123   10007515                                    cardiac arrest     667
# 1237   10008190                          cerebrovascular accident    1050
# 1273   10008469                                  chest discomfort     876
# 1274   10008479                                        chest pain    1765
# 1281   10008531                                            chills    1266
# 1454   10010144                                 completed suicide     847
# 1471   10010264                              condition aggravated    2382
# 1475   10010305                                 confusional state    1254
# 1544   10010774                                      constipation    2149
# 1601   10011224                                             cough    2636
# 1715   10011906                                             death    7781
# 1756   10012378                                        depression    1767
# 1878   10013654                                        drug abuse     391
# 1884   10013710                                  drug interaction    1038
# 1930   10013968                                          dyspnoea    5205
# 2244   10016173                                              fall    2851
# 2272   10016322                                  feeling abnormal    2328
# 2324   10016807                                   fluid retention     678
# 2327   10016825                                          flushing     841
# 2389   10017577                                  gait disturbance    1540
# 2466   10017955                      gastrointestinal haemorrhage     904
# 2609   10018884                             haemoglobin decreased     896
# 2640   10019063                                     hallucination     633
# 2872   10020772                                      hypertension    1517
# 2898   10020937                                     hypoaesthesia    1293
# 2944   10021097                                       hypotension    2596
# 3049   10022000                                         influenza    1543
# 3097   10022437                                          insomnia    2065
# 3200   10023232                                    joint swelling    1168
# 3569   10027175                                 memory impairment    1145
# 3667   10027599                                          migraine     873
# 3900   10029331                             neuropathy peripheral    1000
# 3974   10030124                                 oedema peripheral     871
# 4130   10033295                                          overdose    1076
# 4140   10033371                                              pain    4859
# 4141   10033425                                 pain in extremity    3449
# 4150   10033557                                      palpitations     876
# 4190   10033775                                      paraesthesia    1235
# 4401   10035528                          platelet count decreased     959
# 4425   10035664                                         pneumonia    3493
# 4642   10037153                                         psoriasis    2073
# 4735   10037660                                           pyrexia    2925
# 4893   10038695                               respiratory failure     907
# 5088   10039906                                           seizure    1281
# 5110   10040047                                            sepsis    1159
# 5163   10040753                                         sinusitis    1215
# 5248   10041349                                        somnolence    1459
# 5646   10044565                                            tremor    1459
# 5777   10046571                           urinary tract infection    1989
# 5940   10047513                                    vision blurred    1018
# 6018   10047895                                  weight decreased    2546
# 6020   10047899                                  weight increased    1963
# 6028   10047942                  white blood cell count decreased    1355
# 6237   10048959                               peripheral swelling    2305
# 7783   10053762                                     off label use   22918
# 7893   10054112                                   hospitalisation    2093
# 9699   10061428                                decreased appetite    2283
# 9826   10061623                             adverse drug reaction    1948
# 10269  10062355                                 unevaluable event     902
# 10628  10063829                                device malfunction     439
# 11387  10066377                               therapy interrupted       0
# 11486  10066901                                 treatment failure    1189
# 12163  10069216                             device adhesion issue       4
# 12823  10071408                maternal exposure during pregnancy     540
# 13149  10072878                                  device use error      23
# 13276  10073317                    accidental exposure to product    2210
# 13694  10074903                        intentional product misuse    1569
# 14080  10076308                     intentional product use issue     591
# 14112  10076476              product use in unapproved indication    2307
# 15156  10081572  inappropriate schedule of product administration      22
# 15440  10084268                                          covid-19       0
#
#        2019_A  2020_A   2019_Delta
# 169       436    1222     1.802752
# 246      1482    1629     0.099190
# 355      1777    2113     0.189083
# 433      3266    3744     0.146356
# 470      2957    3074     0.039567
# 534      2121    2322     0.094767
# 903      1020    1095     0.073529
# 1123      725    1331     0.835862
# 1237     1098    1197     0.090164
# 1273      826    1005     0.216707
# 1274     1595    1790     0.122257
# 1281      931    1042     0.119227
# 1454     1250    1483     0.186400
# 1471     2607    3072     0.178366
# 1475     1229    1638     0.332791
# 1544     2341    2399     0.024776
# 1601     2451    2874     0.172583
# 1715     7744   10010     0.292614
# 1756     1767    1807     0.022637
# 1878      952    1185     0.244748
# 1884     1269    1339     0.055162
# 1930     5414    6130     0.132250
# 2244     2844    3669     0.290084
# 2272     2233    2371     0.061800
# 2324      826    1138     0.377724
# 2327      980    1094     0.116327
# 2389     1347    1758     0.305122
# 2466      914    1462     0.599562
# 2609      957    1241     0.296761
# 2640      699    1610     1.303290
# 2872     1358    1638     0.206186
# 2898     1270    1284     0.011024
# 2944     2286    2570     0.124234
# 3049     1284    1432     0.115265
# 3097     1971    2238     0.135464
# 3200      939    1003     0.068158
# 3569     1152    1482     0.286458
# 3667      986    1085     0.100406
# 3900      994    1817     0.827968
# 3974      815    1168     0.433129
# 4130     1159    1175     0.013805
# 4140     4316    5169     0.197637
# 4141     2613    3014     0.153463
# 4150      914    1073     0.173961
# 4190     1122    1176     0.048128
# 4401     1003    1065     0.061815
# 4425     3708    4021     0.084412
# 4642     2134    2328     0.090909
# 4735     2762    3160     0.144098
# 4893      871    1130     0.297359
# 5088     1635    1684     0.029969
# 5110     1247    1388     0.113071
# 5163     1048    1388     0.324427
# 5248     1580    1668     0.055696
# 5646     1260    1439     0.142063
# 5777     1735    2272     0.309510
# 5940     1024    1144     0.117188
# 6018     2374    2635     0.109941
# 6020     2075    2197     0.058795
# 6028     1386    1606     0.158730
# 6237     2136    2511     0.175562
# 7783     8550    8844     0.034386
# 7893     2594    3198     0.232845
# 9699     2117    2274     0.074162
# 9826     1131    1290     0.140584
# 10269     930    1228     0.320430
# 10628     821    1739     1.118149
# 11387       1    2054  2053.000000
# 11486     930    4304     3.627957
# 12163     189    2039     9.788360
# 12823     700    1042     0.488571
# 13149     266    2754     9.353383
# 13276    2236    2532     0.132379
# 13694     806    1032     0.280397
# 14080    1186    2109     0.778246
# 14112    2834    3816     0.346507
# 15156    1772    1811     0.022009
# 15440       0    1674          inf

# %%
uncondition_2019_history[uncondition_2019_history.name=='cough']
# Out:
#             SE   name  2013_A  2013_B  2014_A  2014_B  2015_A  2015_B  2016_A  \
# 1601  10011224  cough    1113   88221    1269   96535    2474  176909    2140
#
#       2016_B  2017_A  2017_B  2018_A  2018_B  2019_A  2019_B  2020_A  2020_B  \
# 1601  167093    2503  208233    2636  241369    2451  218469    2874  208278
#
#       2013_ROR  2014_ROR  2015_ROR  2016_ROR  2017_ROR  2018_ROR  2019_ROR  \
# 1601  1.093755  1.049703  0.986719  1.077427  1.147974  1.263512  1.229957
#
#       2013_Delta  2014_Delta  2015_Delta  2016_Delta  2017_Delta  2018_Delta  \
# 1601     1.58221    1.264775    0.161681    0.342991    0.148222    0.090288
#
#       2019_Delta
# 1601    0.172583

# %% [markdown]
# ## Population distribution

# %%
all_pd_US_pro = pickle.load(open('../Data/pandemic/all_pd_US_pro.pk', 'rb'))  # update the dataframe with ROR and Delta
len(all_pd_US_pro)
# Out:
# 2551071

# %%
st = '-03-10'
end = '-09-31'
ind = [st<i[4:]<end for i in all_pd_US_pro['receipt_date']]
all_pd_US_pro_period= all_pd_US_pro[ind]
n_all = len(all_pd_US_pro_period)
print('the #-reports during March 11-Sept 30, accmulated from 2013-2020', n_all)

n_male = len(all_pd_US_pro_period[all_pd_US_pro_period.gender=='1'])
n_female = len(all_pd_US_pro_period[all_pd_US_pro_period.gender=='2'])

in_young = [str(0)<str(i)<str(20) for i in all_pd_US_pro_period.age]

in_adult = [str(19)<str(i)<str(65) for i in all_pd_US_pro_period.age]

in_elderly = [str(64)<str(i) for i in all_pd_US_pro_period.age]
n_young = len(all_pd_US_pro_period[in_young])
n_adult = len(all_pd_US_pro_period[in_adult])
n_elderly = len(all_pd_US_pro_period[in_elderly])

# unknown sex: 
n_unknownsex = n_all-n_male-n_female
n_unknownage = n_all - n_young -n_adult-n_elderly
print('#-male reports',n_male, n_male/n_all)
print('#-female reports',n_female, n_female/n_all)
print('unknown sex: ', n_unknownsex, n_unknownsex/n_all)

# unknown age
print('#-young reports', n_young, n_young/n_all)

print('#-adult reports', n_adult, n_adult/n_all)

print('#-elderly reports',n_elderly, n_elderly/n_all)
print('unknown age', n_unknownage, n_unknownage/n_all)
# Out:
# the #-reports during March 11-Sept 30, accmulated from 2013-2020 1425371
# #-male reports 484649 0.3400160379297741
# #-female reports 784230 0.5501935987192107
# unknown sex:  156492 0.10979036335101527
# #-young reports 35987 0.025247461888869633
# #-adult reports 508983 0.357088084435561
# #-elderly reports 305685 0.21445995463637185
# unknown age 574716 0.40320449903919753

# %%
## mean and std average
young_age = np.array(list(all_pd_US_pro_period[in_young].age))
print(young_age.mean(), young_age.std())

adult_age = np.array(list(all_pd_US_pro_period[in_adult].age))
print(adult_age.mean(), adult_age.std())

elderly_age = np.array(list(all_pd_US_pro_period[in_elderly].age))
print(elderly_age.mean(), elderly_age.std())
# Out:
# 13.988801511656987 9.009386593710554
# 47.78402422084824 13.198427571170923
# 72.98214501856486 11.0588864576358

# %%
# "1= Physician
# 2= Pharmacist
# 3= Other Health Professional
# 4= Lawyer
# 5= Consumer"

## Qualification/reporter distribution
all_pd = pickle.load(open('../Data/curated/patient_safety.pk', 'rb'))  
print('#-of all reports',all_pd.shape)

all_pd_US = all_pd[all_pd.country=='US']
print('Focus on US, reports #', all_pd_US.shape)

st = '-03-10'
end = '-09-31'
ind = [st<i[4:]<end for i in all_pd_US['receipt_date']]
all_pd_US_period= all_pd_US[ind]

all_pd_US_period['qualify'].value_counts()
# Out:
# #-of all reports (9325731, 23)
# Focus on US, reports # (6351817, 23)
# 5    2045491
# 1     594787
# 3     548261
# 2     282323
# 6     124447
# 4     113744
# 0        478
# Name: qualify, dtype: int64

# %% [markdown]
# # Conditioned on Gender

# %% [markdown]
# ## Male

# %%
all_pd_US_pro_male = all_pd_US_pro[all_pd_US_pro.gender=='1']

DF = all_pd_US_pro_male
# reports in 2020 
"""initialize the Data frame """
# SE_list = list(SE_dic_df.code)
# male_matrix = pd.DataFrame({'SE': SE_list, 'name':list(SE_dic_df.index), 'medra_ID': list(SE_dic_df['medra_ID'])})

SE_list = list(sorted(set(list(itertools.chain(*DF.SE)))))
ind = [i in SE_list for i in meddra_pd_all.PT]
whatever_ = meddra_pd_all[ind]
male_matrix = pd.DataFrame({'SE': list(whatever_.PT), 'name':list(whatever_['PT_name']) }) 


yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
for yr in yr_list:
    st = str(yr)+'-03-10'
    end = str(yr)+'-09-31'
    ind = [st<i<end for i in DF['receipt_date']]
    locals()['all_pd_US_pro_'+str(yr)]= DF[ind]
    print('rows in {}:{}'.format(yr,len(locals()['all_pd_US_pro_'+str(yr)])))

    n_report = len(locals()['all_pd_US_pro_'+str(yr)])
    print('{} year has {} reports'.format(yr, n_report))
    A =[]
    for se in tqdm(SE_list):
        name = locals()['all_pd_US_pro_'+str(yr)]
        indx = [se in j for j in name.SE]
        n_A = sum(indx)
        A.append(n_A)
    B = [n_report - i for i in A]
    male_matrix[str(yr)+'_A'] = A
    male_matrix[str(yr)+'_B'] = B
# Out:
#   0%|          | 11/12439 [00:00<01:54, 108.94it/s]
# rows in 2013:30468
# 2013 year has 30468 reports
# 100%|██████████| 12439/12439 [01:52<00:00, 110.35it/s]
#   0%|          | 9/12439 [00:00<02:26, 85.10it/s]
# rows in 2014:33824
# 2014 year has 33824 reports
# 100%|██████████| 12439/12439 [02:08<00:00, 96.86it/s]
#   0%|          | 5/12439 [00:00<04:44, 43.63it/s]
# rows in 2015:63073
# 2015 year has 63073 reports
# 100%|██████████| 12439/12439 [04:30<00:00, 45.96it/s]
#   0%|          | 5/12439 [00:00<04:12, 49.24it/s]
# rows in 2016:58998
# 2016 year has 58998 reports
# 100%|██████████| 12439/12439 [04:11<00:00, 49.43it/s]
#   0%|          | 4/12439 [00:00<05:39, 36.58it/s]
# rows in 2017:71237
# 2017 year has 71237 reports
# 100%|██████████| 12439/12439 [05:22<00:00, 38.59it/s]
#   0%|          | 4/12439 [00:00<06:04, 34.14it/s]
# rows in 2018:79623
# 2018 year has 79623 reports
# 100%|██████████| 12439/12439 [06:02<00:00, 34.29it/s]
#   0%|          | 4/12439 [00:00<05:49, 35.56it/s]
# rows in 2019:73675
# 2019 year has 73675 reports
# 100%|██████████| 12439/12439 [05:41<00:00, 36.42it/s]
#   0%|          | 4/12439 [00:00<05:46, 35.85it/s]
# rows in 2020:72733
# 2020 year has 72733 reports
# 100%|██████████| 12439/12439 [05:18<00:00, 39.06it/s]

# %%
male_matrix.head(3)
# Out:
#          SE                          name  2013_A  2013_B  2014_A  2014_B  \
# 0  10000029  5-alpha-reductase deficiency       0   30468       0   33824
# 1  10000044              abdomen crushing       0   30468       0   33824
# 2  10000050           abdominal adhesions       5   30463       1   33823
#
#    2015_A  2015_B  2016_A  2016_B  2017_A  2017_B  2018_A  2018_B  2019_A  \
# 0       0   63073       0   58998       0   71237       0   79623       0
# 1       0   63073       0   58998       0   71237       0   79623       0
# 2       7   63066       3   58995       9   71228       4   79619       4
#
#    2019_B  2020_A  2020_B
# 0   73675       1   72732
# 1   73675       1   72732
# 2   73671       7   72726

# %%
pickle.dump(male_matrix, open('../Data/pandemic/SE_male_raw.pk', 'wb'))

# %%
para_male = male_matrix
yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019]
for yr in yr_list:  # calculate ROR  
    para_male[str(yr)+'_ROR'] = (para_male['2020_A']*para_male[str(yr)+'_B'])/(para_male['2020_B']*para_male[str(yr)+'_A'])

for yr in yr_list:  # calculate Delta: average difference  
    para_male[str(yr)+'_Delta'] = (para_male['2020_A'] - para_male[str(yr)+'_A'])/para_male[str(yr)+'_A']

pd.set_option('display.max_columns', None)
"""Note: 0/0 = NaN, 1/0 = inf"""
para_male.head()
# Out:
#          SE                          name  2013_A  2013_B  2014_A  2014_B  \
# 0  10000029  5-alpha-reductase deficiency       0   30468       0   33824
# 1  10000044              abdomen crushing       0   30468       0   33824
# 2  10000050           abdominal adhesions       5   30463       1   33823
# 3  10000059          abdominal discomfort     188   30280     176   33648
# 4  10000060          abdominal distension     120   30348     150   33674
#
#    2015_A  2015_B  2016_A  2016_B  2017_A  2017_B  2018_A  2018_B  2019_A  \
# 0       0   63073       0   58998       0   71237       0   79623       0
# 1       0   63073       0   58998       0   71237       0   79623       0
# 2       7   63066       3   58995       9   71228       4   79619       4
# 3     444   62629     482   58516     653   70584     806   78817     674
# 4     234   62839     191   58807     280   70957     393   79230     304
#
#    2019_B  2020_A  2020_B  2013_ROR  2014_ROR  2015_ROR  2016_ROR  2017_ROR  \
# 0   73675       1   72732       inf       inf       inf       inf       inf
# 1   73675       1   72732       inf       inf       inf       inf       inf
# 2   73671       7   72726  0.586423  3.255521  0.867173  1.892789  0.761757
# 3   73001     582   72151  1.299208  1.542152  1.137819  0.979283  0.871914
# 4   73371     265   72468  0.924801  0.820924  0.982003  1.125888  0.926695
#
#    2018_ROR  2019_ROR  2013_Delta  2014_Delta  2015_Delta  2016_Delta  \
# 0       inf       inf         inf         inf         inf         inf
# 1       inf       inf         inf         inf         inf         inf
# 2  1.915866  1.772739    0.400000    6.000000    0.000000    1.333333
# 3  0.788797  0.873674    2.095745    2.306818    0.310811    0.207469
# 4  0.737219  0.882573    1.208333    0.766667    0.132479    0.387435
#
#    2017_Delta  2018_Delta  2019_Delta
# 0         inf         inf         inf
# 1         inf         inf         inf
# 2   -0.222222    0.750000    0.750000
# 3   -0.108729   -0.277916   -0.136499
# 4   -0.053571   -0.325700   -0.128289

# %%
pickle.dump(para_male, open('../Data/pandemic/SE_male.pk', 'wb'))  # update the dataframe with ROR and Delta

# %% [markdown]
# ## Female

# %%
all_pd_US_pro_female = all_pd_US_pro[all_pd_US_pro.gender=='2']

DF = all_pd_US_pro_female
# reports in 2020 
"""initialize the Data frame """
# SE_list = list(SE_dic_df.code)
# female_matrix = pd.DataFrame({'SE': SE_list, 'name':list(SE_dic_df.index), 'medra_ID': list(SE_dic_df['medra_ID'])})
SE_list = list(sorted(set(list(itertools.chain(*DF.SE)))))
ind = [i in SE_list for i in meddra_pd_all.PT]
whatever_ = meddra_pd_all[ind]
female_matrix = pd.DataFrame({'SE': list(whatever_.PT), 'name':list(whatever_['PT_name']) }) 

yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
for yr in yr_list:
    st = str(yr)+'-03-10'
    end = str(yr)+'-09-31'
    ind = [st<i<end for i in DF['receipt_date']]
    locals()['all_pd_US_pro_'+str(yr)]= DF[ind]
    print('rows in {}:{}'.format(yr,len(locals()['all_pd_US_pro_'+str(yr)])))

    n_report = len(locals()['all_pd_US_pro_'+str(yr)])
    print('{} year has {} reports'.format(yr, n_report))
    A =[]
    for se in tqdm(SE_list):
        name = locals()['all_pd_US_pro_'+str(yr)]
        indx = [se in j for j in name.SE]
        n_A = sum(indx)
        A.append(n_A)
    B = [n_report - i for i in A]
    female_matrix[str(yr)+'_A'] = A
    female_matrix[str(yr)+'_B'] = B
# Out:
#   0%|          | 7/13433 [00:00<03:27, 64.76it/s]
# rows in 2013:50468
# 2013 year has 50468 reports
# 100%|██████████| 13433/13433 [03:25<00:00, 65.42it/s]
#   0%|          | 6/13433 [00:00<03:51, 57.92it/s]
# rows in 2014:55218
# 2014 year has 55218 reports
# 100%|██████████| 13433/13433 [03:46<00:00, 59.28it/s]
#   0%|          | 4/13433 [00:00<07:00, 31.97it/s]
# rows in 2015:97402
# 2015 year has 97402 reports
# 100%|██████████| 13433/13433 [07:05<00:00, 31.57it/s]
#   0%|          | 4/13433 [00:00<06:42, 33.36it/s]
# rows in 2016:91947
# 2016 year has 91947 reports
# 100%|██████████| 13433/13433 [06:42<00:00, 33.38it/s]
#   0%|          | 3/13433 [00:00<08:59, 24.89it/s]
# rows in 2017:114661
# 2017 year has 114661 reports
# 100%|██████████| 13433/13433 [08:37<00:00, 25.96it/s]
#   0%|          | 3/13433 [00:00<10:33, 21.21it/s]
# rows in 2018:141138
# 2018 year has 141138 reports
# 100%|██████████| 13433/13433 [10:09<00:00, 22.03it/s]
#   0%|          | 3/13433 [00:00<09:10, 24.40it/s]
# rows in 2019:117965
# 2019 year has 117965 reports
# 100%|██████████| 13433/13433 [08:53<00:00, 25.19it/s]
#   0%|          | 3/13433 [00:00<09:17, 24.08it/s]
# rows in 2020:113907
# 2020 year has 113907 reports
# 100%|██████████| 13433/13433 [08:49<00:00, 25.37it/s]

# %%
pickle.dump(female_matrix, open('../Data/pandemic/SE_female_raw.pk', 'wb'))

# %%
para_female = female_matrix
yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019]
for yr in yr_list:  # calculate ROR  
    para_female[str(yr)+'_ROR'] = (para_female['2020_A']*para_female[str(yr)+'_B'])/(para_female['2020_B']*para_female[str(yr)+'_A'])

for yr in yr_list:  # calculate Delta: average difference  
    para_female[str(yr)+'_Delta'] = (para_female['2020_A'] - para_female[str(yr)+'_A'])/para_female[str(yr)+'_A']

pd.set_option('display.max_columns', None)
"""Note: 0/0 = NaN, 1/0 = inf"""
para_female.head()
# Out:
#          SE                  name  2013_A  2013_B  2014_A  2014_B  2015_A  \
# 0  10000044      abdomen crushing       0   50468       0   55218       0
# 1  10000050   abdominal adhesions       9   50459      13   55205       9
# 2  10000059  abdominal discomfort     344   50124     410   54808     881
# 3  10000060  abdominal distension     237   50231     262   54956     500
# 4  10000077        abdominal mass       6   50462      11   55207       8
#
#    2015_B  2016_A  2016_B  2017_A  2017_B  2018_A  2018_B  2019_A  2019_B  \
# 0   97402       0   91947       0  114661       0  141138       0  117965
# 1   97393       3   91944      12  114649      10  141128      10  117955
# 2   96521     891   91056    1226  113435    1469  139669    1298  116667
# 3   96902     391   91556     562  114099     618  140520     564  117401
# 4   97394      11   91936       7  114654       9  141129      15  117950
#
#    2020_A  2020_B  2013_ROR  2014_ROR  2015_ROR  2016_ROR  2017_ROR  2018_ROR  \
# 0       0  113907       NaN       NaN       NaN       NaN       NaN       NaN
# 1       5  113902  0.246113  0.186412  0.475033  1.345367  0.419399  0.619515
# 2    1272  112635  1.645512  1.509642  1.237256  1.154103  1.044889  1.073722
# 3     593  113314  1.109161  1.097703  1.014224  1.225409  1.062470  1.189928
# 4      10  113897  0.738416  0.440645  1.068882  0.733805  1.438066  1.376770
#
#    2019_ROR  2013_Delta  2014_Delta  2015_Delta  2016_Delta  2017_Delta  \
# 0       NaN         NaN         NaN         NaN         NaN         NaN
# 1  0.517792   -0.444444   -0.615385   -0.444444    0.666667   -0.583333
# 2  1.015049    2.697674    2.102439    0.443814    0.427609    0.037520
# 3  1.089341    1.502110    1.263359    0.186000    0.516624    0.055160
# 4  0.690390    0.666667   -0.090909    0.250000   -0.090909    0.428571
#
#    2018_Delta  2019_Delta
# 0         NaN         NaN
# 1   -0.500000   -0.500000
# 2   -0.134105   -0.020031
# 3   -0.040453    0.051418
# 4    0.111111   -0.333333

# %%
pickle.dump(para_female, open('../Data/pandemic/SE_female.pk', 'wb'))  # update the dataframe with ROR and Delta

# %% [markdown]
# # Conditioned on Age
#
# Based on [WHO](https://www.who.int/hiv/pub/guidelines/arv2013/intro/keyterms/en/) and the [Men Ageing And Health](https://apps.who.int/iris/bitstream/handle/10665/66941/WHO_NMH_NPH_01.2.pdf;jsessionid=A48157B9B4DFAA3A9874176D8A7C2894?sequence=1), the age group:
#
# - Young: 1-19
# - Adult: 20-65
# - Elderly: >65

# %% [markdown]
# ## Bin age into groups

# %%
age_US_df = pickle.load(open('../Data/pandemic/all_pd_US_pro.pk', 'rb'))  # update the dataframe with ROR and Delta

# Bin age into groups 
age_US_df['age'] = pd.to_numeric(age_US_df['age'], errors='coerce')
bins = [1, 20, 65, max(age_US_df.age)+1] 
age_labels = ['young', 'adult','elderly']
age_US_df['age_group'] = pd.cut(age_US_df.age, bins, right = False, labels= age_labels)

# %% [markdown]
# ## Three age groups

# %%
for age in age_labels:
    age_US_df_group = age_US_df[age_US_df.age_group==age]

    DF = age_US_df_group
    # reports in 2020 
    """initialize the Data frame """
#     SE_list = list(SE_dic_df.code)
#     age_matrix = pd.DataFrame({'SE': SE_list, 'name':list(SE_dic_df.index), 'medra_ID': list(SE_dic_df['medra_ID'])})
    """Remember sort the SE set!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!11"""
    SE_list = list(sorted(set(list(itertools.chain(*DF.SE)))))
    ind = [i in SE_list for i in meddra_pd_all.PT]
    whatever_ = meddra_pd_all[ind]
    age_matrix = pd.DataFrame({'SE': list(whatever_.PT), 'name':list(whatever_['PT_name']) }) 
    
    
    yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
    for yr in yr_list:
        st = str(yr)+'-03-10'
        end = str(yr)+'-09-31'
        ind = [st<i<end for i in DF['receipt_date']]
        locals()['all_pd_US_pro_'+str(yr)]= DF[ind]
        print('rows in {}:{}'.format(yr,len(locals()['all_pd_US_pro_'+str(yr)])))

        n_report = len(locals()['all_pd_US_pro_'+str(yr)])
        print('{} year has {} reports'.format(yr, n_report))
        A =[] 
        for se in tqdm(SE_list):
            name = locals()['all_pd_US_pro_'+str(yr)]
            indx = [se in j for j in name.SE]
            n_A = sum(indx)
            A.append(n_A)
        B = [n_report - i for i in A]
        age_matrix[str(yr)+'_A'] = A
        age_matrix[str(yr)+'_B'] = B

    pickle.dump(age_matrix, open('../Data/pandemic/SE_'+age+'_raw.pk', 'wb'))

    para_age = age_matrix
    yr_list = [2013, 2014, 2015, 2016, 2017, 2018, 2019]
    for yr in yr_list:  # calculate ROR  
        para_age[str(yr)+'_ROR'] = (para_age['2020_A']*para_age[str(yr)+'_B'])/(para_age['2020_B']*para_age[str(yr)+'_A'])

    for yr in yr_list:  # calculate Delta: average difference  
        para_age[str(yr)+'_Delta'] = (para_age['2020_A'] - para_age[str(yr)+'_A'])/para_age[str(yr)+'_A']

    
    """Note: 0/0 = NaN, 1/0 = inf"""

    pickle.dump(para_age, open('../Data/pandemic/SE_'+age+'.pk', 'wb'))  # update the dataframe with ROR and Delta
    print(age,'related data saved')
# Out:
#   1%|▏         | 93/7105 [00:00<00:07, 922.99it/s]
# rows in 2013:3567
# 2013 year has 3567 reports
# 100%|██████████| 7105/7105 [00:07<00:00, 945.18it/s]
#   1%|          | 79/7105 [00:00<00:08, 787.53it/s]
# rows in 2014:4091
# 2014 year has 4091 reports
# 100%|██████████| 7105/7105 [00:08<00:00, 823.51it/s]
#   1%|          | 64/7105 [00:00<00:11, 638.44it/s]
# rows in 2015:5391
# 2015 year has 5391 reports
# 100%|██████████| 7105/7105 [00:11<00:00, 640.71it/s]
#   1%|          | 60/7105 [00:00<00:11, 591.11it/s]
# rows in 2016:5708
# 2016 year has 5708 reports
# 100%|██████████| 7105/7105 [00:11<00:00, 604.00it/s]
#   1%|          | 48/7105 [00:00<00:14, 471.79it/s]
# rows in 2017:7029
# 2017 year has 7029 reports
# 100%|██████████| 7105/7105 [00:14<00:00, 501.28it/s]
#   1%|          | 46/7105 [00:00<00:15, 456.63it/s]
# rows in 2018:7159
# 2018 year has 7159 reports
# 100%|██████████| 7105/7105 [00:14<00:00, 475.88it/s]
#   1%|          | 42/7105 [00:00<00:16, 416.38it/s]
# rows in 2019:7602
# 2019 year has 7602 reports
# 100%|██████████| 7105/7105 [00:15<00:00, 455.54it/s]
#   1%|          | 49/7105 [00:00<00:14, 481.04it/s]
# rows in 2020:6606
# 2020 year has 6606 reports
# 100%|██████████| 7105/7105 [00:14<00:00, 502.57it/s]
# young related data saved
#   0%|          | 9/12594 [00:00<02:21, 88.88it/s]
# rows in 2013:38512
# 2013 year has 38512 reports
# 100%|██████████| 12594/12594 [02:18<00:00, 90.77it/s]
#   0%|          | 8/12594 [00:00<02:40, 78.50it/s]
# rows in 2014:40632
# 2014 year has 40632 reports
# 100%|██████████| 12594/12594 [02:29<00:00, 84.30it/s]
#   0%|          | 6/12594 [00:00<04:17, 48.92it/s]
# rows in 2015:64769
# 2015 year has 64769 reports
# 100%|██████████| 12594/12594 [04:07<00:00, 50.83it/s]
#   0%|          | 6/12594 [00:00<03:58, 52.81it/s]
# rows in 2016:63836
# 2016 year has 63836 reports
# 100%|██████████| 12594/12594 [04:02<00:00, 52.01it/s]
#   0%|          | 5/12594 [00:00<04:48, 43.69it/s]
# rows in 2017:69955
# 2017 year has 69955 reports
# 100%|██████████| 12594/12594 [04:30<00:00, 46.51it/s]
#   0%|          | 4/12594 [00:00<05:50, 35.94it/s]
# rows in 2018:81578
# 2018 year has 81578 reports
# 100%|██████████| 12594/12594 [05:35<00:00, 37.56it/s]
#   0%|          | 5/12594 [00:00<04:58, 42.11it/s]
# rows in 2019:74209
# 2019 year has 74209 reports
# 100%|██████████| 12594/12594 [05:01<00:00, 41.82it/s]
#   0%|          | 4/12594 [00:00<05:17, 39.67it/s]
# rows in 2020:66258
# 2020 year has 66258 reports
# 100%|██████████| 12594/12594 [04:38<00:00, 45.16it/s]
# adult related data saved
#   0%|          | 20/10283 [00:00<00:51, 199.08it/s]
# rows in 2013:17999
# 2013 year has 17999 reports
# 100%|██████████| 10283/10283 [00:52<00:00, 197.20it/s]
#   0%|          | 17/10283 [00:00<01:03, 161.23it/s]
# rows in 2014:20848
# 2014 year has 20848 reports
# 100%|██████████| 10283/10283 [01:00<00:00, 168.62it/s]
#   0%|          | 10/10283 [00:00<01:51, 91.89it/s]
# rows in 2015:36916
# 2015 year has 36916 reports
# 100%|██████████| 10283/10283 [01:41<00:00, 100.99it/s]
#   0%|          | 9/10283 [00:00<02:14, 76.61it/s]
# rows in 2016:36118
# 2016 year has 36118 reports
# 100%|██████████| 10283/10283 [01:43<00:00, 99.13it/s]
#   0%|          | 8/10283 [00:00<02:11, 77.93it/s]
# rows in 2017:42320
# 2017 year has 42320 reports
# 100%|██████████| 10283/10283 [02:04<00:00, 82.92it/s]
#   0%|          | 7/10283 [00:00<02:35, 66.29it/s]
# rows in 2018:53489
# 2018 year has 53489 reports
# 100%|██████████| 10283/10283 [02:34<00:00, 66.45it/s]
#   0%|          | 7/10283 [00:00<02:29, 68.84it/s]
# rows in 2019:45917
# 2019 year has 45917 reports
# 100%|██████████| 10283/10283 [02:17<00:00, 75.03it/s]
#   0%|          | 7/10283 [00:00<02:32, 67.46it/s]
# rows in 2020:46371
# 2020 year has 46371 reports
# 100%|██████████| 10283/10283 [02:20<00:00, 73.23it/s]
# elderly related data saved

# %%
locals()['all_pd_US_pro_'+str(yr)].head(10)
# Out:
#         version report_id                                           case_id  \
# 7667816       3  10058132                          US-PFIZER INC-2014093363
# 7667849       2  15531775   US-BRISTOL-MYERS SQUIBB COMPANY-BMS-2018-095646
# 7667908       6  15505898                          US-PFIZER INC-2018414114
# 7667948       4  15478711                          US-PFIZER INC-2018399211
# 7668003       2  15545327                          US-PFIZER INC-2018433974
# 7668074       3  15548251  US-ALNYLAM PHARMACEUTICALS, INC.-ALN-2018-000218
# 7668086       2  15540366                          US-PFIZER INC-2018429645
# 7668169       4  13010086                       US-CELGENEUS-USA-2016104725
# 7668172       5  14285441                          US-PFIZER INC-2017532858
# 7668189       2  15598934                          US-PFIZER INC-2018454583
#
#         country qualify serious s1 s2 s3 s4 s5 s6  receivedate  receiptdate  \
# 7667816      US       1       2  0  0  0  0  0  0         5207         7013
# 7667849      US       1       2  0  0  0  0  0  0         6866         7018
# 7667908      US       3       2  0  0  0  0  0  0         6863         7019
# 7667948      US       1       2  0  0  0  0  0  0         6856         7027
# 7668003      US       3       2  0  0  0  0  0  0         6871         7016
# 7668074      US       1       1  0  0  1  0  0  1         6871         7017
# 7668086      US       3       2  0  0  0  0  0  0         6870         7017
# 7668169      US       1       1  0  0  0  0  0  1         6186         7026
# 7668172      US       1       2  0  0  0  0  0  0         6557         7018
# 7668189      US       3       2  0  0  0  0  0  0         6886         7010
#
#          age gender weight                                                 SE  \
# 7667816   74      1      0                               [10013700, 10028813]
# 7667849   67      1  69.39                               [10060933, 10076476]
# 7667908   70      2      0                                         [10013709]
# 7667948   65      2     99                     [10005481, 10018356, 10038428]
# 7668003   73      2      0                                         [10013700]
# 7668074   75      2   71.4                                         [10007882]
# 7668086   66      1      0                                         [10013709]
# 7668169   71      2  58.11  [10016256, 10034754, 10035528, 10037844, 10061...
# 7668172   69      2      0           [10010264, 10022437, 10040851, 10076309]
# 7668189   70      2      0           [10013700, 10013968, 10019211, 10027175]
#
#                                                      drugs  \
# 7667816                                          [DB00482]
# 7667849  [DB00472, DB00572, DB00572, DB00996, DB01039, ...
# 7667908                        [DB00563, DB00563, DB00563]
# 7667948                                 [DB09073, DB09073]
# 7668003                        [DB00318, DB00533, DB01076]
# 7668074  [DB00162, DB00162, DB00181, DB00193, DB00211, ...
# 7668086                                          [DB00230]
# 7668169               [DB00480, DB00480, DB00480, DB00480]
# 7668172  [DB00175, DB00222, DB00230, DB00230, DB00331, ...
# 7668189                                          [DB00295]
#
#                                                indications  lastingdays  \
# 7667816                                         [10033371]         1806
# 7667849  [10030155, 10070592, 10070592, 10070592, 10070...          152
# 7667908                     [10039073, 10039073, 10039073]          156
# 7667948                               [10035226, 10055113]          171
# 7668003                     [10037440, 10037440, 10037440]          145
# 7668074  [10003553, 10003553, 10003553, 10003553, 10003...          146
# 7668086                                         [10029331]          147
# 7668169           [10028533, 10028533, 10070592, 10070592]          840
# 7668172  [10005423, 10012601, 10012601, 10012680, 10020...          461
# 7668189                                         [10072005]          124
#
#                date receipt_date age_group
# 7667816  2014-04-04   2019-03-15   elderly
# 7667849  2018-10-19   2019-03-20   elderly
# 7667908  2018-10-16   2019-03-21   elderly
# 7667948  2018-10-09   2019-03-29   elderly
# 7668003  2018-10-24   2019-03-18   elderly
# 7668074  2018-10-24   2019-03-19   elderly
# 7668086  2018-10-23   2019-03-19   elderly
# 7668169  2016-12-08   2019-03-28   elderly
# 7668172  2017-12-14   2019-03-20   elderly
# 7668189  2018-11-08   2019-03-12   elderly
